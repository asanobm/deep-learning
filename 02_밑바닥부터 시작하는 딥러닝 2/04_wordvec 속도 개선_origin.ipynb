# %% [markdown]
# # 4 word2vec 속도 개선

# %% [markdown]
# ## 4.1 word2vec 개선 1
#
# 앞 장의 CBOW모델은 단어 2개를 맥락으로 사용해, 이를 바탕으로 하나의 단어를 추측한다. 이때 입력 측 가중치$W_{in}$와의 행렬 곱으로 은닉층이 계산되고, 다시 출력층 가중치$W_{out}$와의 행렬 곱으로 각 단어의 점수를 구한다. 그리고 이 점수에 소프트맥스 함수를 적용해 각 단어의 출현 확률을 얻고, 이 확률을 정답 레이블과 비교하여 손실을 구한다.
#
# 말뭉치가 거대해 지면 다음과 같은 문제가 발생한다.
#
# * 입력층의 원핫 표현과 가중치 행렬$W_{in}$의 곱 계산이 너무 느리다.
# * 출력층의 가중치 행렬$W_{out}$과의 곱, 소프트맥스 계산도 느리다.

# %% [markdown]
# ### 4.1.1 Embedding 계층
#
# * Embedding 계층은 단어 ID에 해당하는 행을 추출하는 계층이다.
# * Embedding 계층을 사용하면 단어의 분산 표현을 얻을 수 있다.

# %% [markdown]
# ### 4.1.2 Embedding 계층 구현

# %%
import numpy as np

class Embedding:
  def __init__(self, W):
    self.params = [W]
    self.grads = [np.zeros_like(W)]
    self.idx = None
    
  def forward(self, idx):
    W = self.params
    self.idx = idx
    out = W[idx]
    return out
  
  def backward(self, dout):
    dW, = self.grads
    dW[...] = 0
    np.add.at(dW, self.idx, dout) # type: ignore
    return None

# %% [markdown]
# ## 4.2 word2vec 개선 2
#
# 네거티브 샘플링(Negative Sampling)이란 기법을 사용하여 속도를 개선한다.

# %% [markdown]
# ### 4.2.1 은닉층 이후 계산의 문제점
#
# 은닉층 이후 계산이 오래 걸리는 곳
#
# * 은닉층의 뉴런과 가중치 행렬$W_{out}$의 곱
# * 소프트맥스 함수의 계산
#
# 거대한 말뭉치를 다룰 때 이 행렬의 곱을 계산하려면 많은 계산량이 필요하다.
#
# 소프트맥스에서도 같은 문제가 발생한다.
# $$
# Y_{k} = \frac{exp(S_{k})}{\sum_{i=1}^{1,000,000}exp(S_{i})}
# $$
#
# k번째 단어의 점수$S_{k}$를 계산하려면 모든 단어의 점수를 계산해야 한다. 이 계산량은 말뭉치의 어휘 수에 비례한다.

# %% [markdown]
# ### 4.2.2 다중 분류에서 이진 분류로
#
# 네거티브 샘플링 기법의 핵심 아이디어는 `이진 분류`이다. 이진 분류는 긍정(positive)과 부정(negative) 두 가지 중 하나를 판단하는 문제이다. 이를 이용하면 다중 분류 문제를 여러 개의 이진 분류 문제로 근사할 수 있다.

# %% [markdown]
# ### 4.2.3 시그모이드 함수와 교차 엔트로피 오차
#
# 이진 분류 문제를 신경망으로 풀려면 점수에 `시그모이드 함수`를 적용해 확률로 변환하고, 손실을 구할 때는 손실 함수로 `교차 엔트로피 오차`를 사용한다.
#
# $$
# y = \frac{1}{1+exp(-x)}
# $$
#
# 그래프는 S자 모양이며, 입력값$(x)$은 0에서 1 사이의 실수로 변환된다. 여기서 시그모이드 함수의 출력$y$는 확률로 해석할 수 있다.
#
# 손실은 `교차 엔트로피 오차`를 사용한다.
#
# $$
# L = -(tlogy + (1-t)log(1-y))
# $$
#
# $y$는 출력이고 $t$는 정답 레이블이다. 이 정답 레이블의 값은 0(부정) 또는 1(긍정)이다.

# %%
import numpy as np

class EmbeddingDot:
  """ Embedding 계층과 Dot 계층을 결합한 계층
  Parameters:
    embed: Embedding 계층
    params: 매개변수
    grads: 기울기
    cache: 순전파 시의 계산 결과를 잠시 유지하기 위한 변수
  """
  def __init__(self, W):
    """EmbeddingDot 계층의 초기화

    Args:
      W: 가중치
    
    Returns:
      None
    """
    self.embed = Embedding(W)
    self.params = self.embed.params
    self.grads = self.embed.grads
    self.cache = None
    
    
  def forward(self, h, idx):
    """순전파
    
    Args:
      h: 은닉층 뉴런
      idx: 단어 ID
      
    Returns:
      out: 내적 결과
    """
    target_W = self.embed.forward(idx)
    out = np.sum(target_W * h, axis=1)
    
    self.cache = (h, target_W)
    return out
  
  def backward(self, dout):
    """역전파
    
    Args:
      dout: 상류에서 넘어온 기울기
      
    Returns:
      dh: 하류로 흘려보낼 기울기
    """
    h, target_W = self.cache # type: ignore
    dout = dout.reshape(dout.shape[0], 1)
    
    dtarget_W = dout * h
    self.embed.backward(dtarget_W)
    dh = dout * target_W
    return dh

# %% [markdown]
# ### 4.2.5 네거티브 샘플링
#
# 네거티브 샘플링은 긍정적인 예를 몇 개 선택하고, 그 외에는 모두 부정적인 예로 취급하는 방법이다.
#
# 긍정적인 예에 대해서는 시그모이드 함수의 출력을 1에 가깝게 만들고, 부정적인 예에 대해서는 0에 가깝게 만든다.
#
# 네거티브 샘플링 기법은 긍정적인 예를 타깃으로 한 경우의 손실과 부정적인 예를 몇 개 샘플링하여, 그 부정정직 예에 대한 손실을 더한 값을 **최종 손실**로 한다.

# %% [markdown]
# ### 4.2.6 네거티브 샘플링의 샘플링 기법
#
# 네거티브 샘플링에서는 부정적인 예를 몇 개 샘플링하는데, 이 샘플링을 어떻게 할지가 중요하다.
#
# 말뭉치의 통계 데이터를 기초로 샘플링을 수행한다. 말뭉치에서 자주 등장하는 단어를 많이 추출하고, 드물게 등장하는 단어는 적게 추출한다.
#
# 말뭉치에서 단어별 출현 횟수를 바탕으로 확률분포를 구한다음, 그 확률분포에 따라서 샘플링을 수행한다. 확률분포대로 샘플링하므로 말뭉치에에서 자주 등장하는 단어는 선택될 가능성이 높고 드물게 등장하는 단어는 선택될 가능성이 낮다.

# %%
# 확률 분포에 따라 샘플링하기

import numpy as np

# 0 ~ 9까지의 숫자 중 하나를 무작위로 샘플링
print(np.random.choice(10))
# Out:
# 0

# %% [markdown]
# word2vec의 네거티브 샘플링에서는 말뭉치에서 단어의 출현 횟수에 3/4제곱을 한 값을 확률분포로 사용한다.
# $$
# P'(w_{i}) = \frac{P(w_{i})^{0.75}}{\sum_{j}P(w_{j})^{0.75}}
# $$
#
# 여기서$P(w_{i})$는 i번째 단어의 확률을 뜻한다. 식은 단순히 원래 확률분포의 각 요소를 '0.75 제곱'할 뿐이다.
#
# 단, 수정 후에도 확률의 총 합은 1이 되어야하므로, 문모로는 '수정 후 확률분포의 총합'이 필요하다.
#
# 0.75를 곱하는 이유는 출현 확률이 낮은 단어를 '버리지 않기' 위해서다.

# %% [markdown]
# **UnigramSampler Class**
#
# UnigramSampler클래스는 확률 분포를 만들고 다시 0.75를 제곱하는 처리를 담당한다.

# %%
from common.np import *
import collections

class UnigramSampler:
  def __init__(self, corpus, power, sample_size):
    self.sample_size = sample_size
    self.vocab_size = None
    self.ward_p = None
    
    counts = collections.Counter()
    for word_id in corpus:
      counts[word_id] += 1
      
    vocab_size = len(counts)
    self.vocab_size = vocab_size
    
    self.word_p = np.zeros(vocab_size)
    for i in range(vocab_size):
      self.word_p[i] = counts[i]
      
    self.word_p = np.power(self.word_p, power)
    self.word_p /= np.sum(self.word_p)
    
  def get_negative_sample(self, target):
    batch_size = target.shape[0]

    if not GPU:
      negative_sample = np.zeros((batch_size, self.sample_size), dtype=np.int32)
      
      for i in range(batch_size):
        p = self.word_p.copy()
        target_idx = target[i]
        p[target_idx] = 0
        p /= p.sum()
        negative_sample[i, :] = np.random.choice(self.vocab_size, size=self.sample_size, replace=False, p=p)
        
    else:
      # GPU(cupy）로 계산할 때는 속도를 우선한다.
      # 부정적 예에 타깃이 포함될 수 있다.
      negative_sample = np.random.choice(self.vocab_size, size=(batch_size, self.sample_size), replace=True, p=self.word_p)
      
    return negative_sample

# %%
corpus = np.array([0, 1, 2, 3, 4, 1, 2, 3])
power = 0.75
sample_size = 2

sampler = UnigramSampler(corpus, power, sample_size)
target = np.array([1, 3, 0])
negative_sample = sampler.get_negative_sample(target)
print(negative_sample)
# Out:
# [[3 2]
#  [1 2]
#  [2 3]]

# %% [markdown]
# ### 4.2.7 네거티브 샘플링 구현

# %%
from common.layers import SigmoidWithLoss

class NegativeSamplingLoss:
  def __init__(self, W, corpus, power=0.75, sample_size=5):
    """NegativeSamplingLoss 클래스의 초기화
    
    Args:
      W: 가중치
      corpus: 말뭉치
      power: 0.75
      sample_size: 샘플링 횟수
      
    Returns:
      None
    
    """
    self.sample_size = sample_size
    self.sampler = UnigramSampler(corpus, power, sample_size) # UnigramSampler 클래스의 인스턴스 (부정적 예 샘플링)
    self.loss_layers = [SigmoidWithLoss() for _ in range(sample_size + 1)] # `sample_size`는 부정적 예의 샘플링 횟수 +1 은 긍정적 예
    self.embed_dot_layers = [EmbeddingDot(W) for _ in range(sample_size + 1)] # `sample_size`는 부정적 예의 샘플링 횟수 +1 은 긍정적 예
    
    # 모든 가중치와 기울기를 리스트에 모은다.
    self.params, self.grads = [], []
    # 각 계층의 가중치와 기울기를 params, grads에 추가
    for layer in self.embed_dot_layers:
      self.params += layer.params
      self.grads += layer.grads
      
      
  def forward(self, h, target):
    """순전파
    
    순전파 에서는 `self.sampler`를 이용해 부정적 예를 샘플링하여 `negative_sample`에 저장한다.
    긍정적 예와 부정적 예 각각의 데이터에 대해서 순전파를 수행해 그 손실들을 더한다.
    
    Args:
      h: 은닉층 뉴런
      target: 긍정적 예의 타깃 단어 ID
      
    Returns:
      loss: 손실
    """
    batch_size = target.shape[0]
    negative_sample = self.sampler.get_negative_sample(target)
    
    # 긍정적 예 순전파
    score = self.embed_dot_layers[0].forward(h, target)
    corrent_label = np.ones(batch_size, dtype=int)
    loss = self.loss_layers[0].forward(score, corrent_label)
    
    # 부정적 예 순전파
    negative_label = np.zeros(batch_size, dtype=int)
    for i in range(self.sample_size):
      negative_target = negative_sample[:, i]
      score = self.embed_dot_layers[1 + i].forward(h, negative_target)
      loss += self.loss_layers[1 + i].forward(score, negative_label)
      
    return loss
  
  def backward(self, dout=1):
    """역전파
    
    Args:
      dout: 상류에서 넘어온 기울기
      
    Returns:
      dh: 하류로 흘려보낼 기울기
    """
    dh = 0
    for l0, l1 in zip(self.loss_layers, self.embed_dot_layers):
      dscore = l0.backward(dout)
      dh += l1.backward(dscore)
    return dh

# %% [markdown]
# ## 4.3 개선판 word2vec 학습
#
# PTB 데이터셋을 사용해 개선된 word2vec을 학습시켜보자.

# %% [markdown]
# ### 4.3.1 CBOW 모델 구현
#
# `SimpleCBOW` 클래스를 개선하여 `CBOW` 클래스를 구현한다.
#
# **개선점**
# * Embedding 계층 사용
# * 은닉층 이후 계산의 개선 (Negative Sampling Loss 계층 사용)

# %%
import numpy as np
from common.layers import Embedding

class CBOW:
  def __init__(self, vocab_size, hidden_size, window_size, corpus):
    """CBOW 모델의 초기화
    
    Args:
      vocab_size: 어휘 수
      hidden_size: 은닉층의 뉴런 수
      window_size: 맥락의 크기
      corpus: 말뭉치 데이터
      
    Returns:
      None
    """
    V, H = vocab_size, hidden_size
    
    # 가중치 초기화
    W_in = 0.01 * np.random.randn(V, H).astype('f')
    W_out = 0.01 * np.random.randn(V, H).astype('f')
    
    # 계층 생성
    self.in_layers = []
    for _ in range(2 * window_size): # Embedding 계층을 2 * window_size 만큼 생성
      layer = Embedding(W_in)
      self.in_layers.append(layer)
      
    self.ns_loss = NegativeSamplingLoss(W_out, corpus, power=0.75, sample_size=5)
    
    # 모든 가중치와 기울기를 리스트에 모은다.
    layers = self.in_layers + [self.ns_loss]
    self.params, self.grads = [], []
    for layer in layers:
      self.params += layer.params
      self.grads += layer.grads
      
    # 인스턴스 변수에 단어의 분산 표현을 저장한다.
    self.word_vecs = W_in
    
  def forward(self, contexts, target):
    h = 0
    for i , layer in enumerate(self.in_layers):
      h += layer.forward(contexts[:, i])
    h *= 1 / len(self.in_layers)
    loss = self.ns_loss.forward(h, target)
    return loss
  
  def backward(self, dout=1):
    dout = self.ns_loss.backward(dout)
    dout *= 1 / len(self.in_layers)
    for layer in self.in_layers:
      layer.backward(dout)
    return None

# %% [markdown]
# ### 4.3.2 CBOW 모델 학습

# %%
import numpy as np
import pickle
from common import config
from common.trainer import Trainer
from common.optimizer import Adam
from common.util import create_contexts_target, to_cpu, to_gpu
from dataset import ptb

config.GPU = False

# 하이퍼파라미터 설정
window_size = 5
hidden_size = 100
batch_size = 100
max_epoch = 10

# 데이터 읽기
corpus, word_to_id, id_to_word = ptb.load_data('train')
vocab_size = len(word_to_id)

print("말뭉치 안의 어휘 수: {:,}".format(vocab_size))

contexts, target = create_contexts_target(corpus, window_size)
if config.GPU:
  contexts, target = to_gpu(contexts), to_gpu(target)
  
# 모델 등 생성
model = CBOW(vocab_size, hidden_size, window_size, corpus)
optimizer = Adam()
trainer = Trainer(model, optimizer)

# 학습 시작
trainer.fit(contexts, target, max_epoch, batch_size)
trainer.plot()

# 나중을 위해서 필요한 데이터 저장
word_vecs = model.word_vecs
if config.GPU:
  word_vecs = to_cpu(word_vecs)
  
  params = {}
  params['word_vecs'] = word_vecs.astype(np.float16)
  params['word_to_id'] = word_to_id
  params['id_to_word'] = id_to_word
  pkl_file = 'cbow_params.pkl'
  with open(pkl_file, 'wb') as f:
    pickle.dump(params, f, -1)
# Out:
# 말뭉치 안의 어휘 수: 10,000
# | epoch 1 |  iter 1 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 21 / 9295 | time 0[s] | loss 4.16
# | epoch 1 |  iter 41 / 9295 | time 1[s] | loss 4.15
# | epoch 1 |  iter 61 / 9295 | time 1[s] | loss 4.12
# | epoch 1 |  iter 81 / 9295 | time 2[s] | loss 4.05
# | epoch 1 |  iter 101 / 9295 | time 2[s] | loss 3.93
# | epoch 1 |  iter 121 / 9295 | time 3[s] | loss 3.77
# | epoch 1 |  iter 141 / 9295 | time 3[s] | loss 3.62
# | epoch 1 |  iter 161 / 9295 | time 4[s] | loss 3.48
# | epoch 1 |  iter 181 / 9295 | time 4[s] | loss 3.35
# | epoch 1 |  iter 201 / 9295 | time 5[s] | loss 3.25
# | epoch 1 |  iter 221 / 9295 | time 5[s] | loss 3.16
# | epoch 1 |  iter 241 / 9295 | time 6[s] | loss 3.09
# | epoch 1 |  iter 261 / 9295 | time 7[s] | loss 3.01
# | epoch 1 |  iter 281 / 9295 | time 7[s] | loss 2.97
# | epoch 1 |  iter 301 / 9295 | time 8[s] | loss 2.91
# | epoch 1 |  iter 321 / 9295 | time 8[s] | loss 2.88
# | epoch 1 |  iter 341 / 9295 | time 9[s] | loss 2.83
# | epoch 1 |  iter 361 / 9295 | time 9[s] | loss 2.83
# | epoch 1 |  iter 381 / 9295 | time 10[s] | loss 2.76
# | epoch 1 |  iter 401 / 9295 | time 10[s] | loss 2.77
# | epoch 1 |  iter 421 / 9295 | time 11[s] | loss 2.76
# | epoch 1 |  iter 441 / 9295 | time 11[s] | loss 2.72
# | epoch 1 |  iter 461 / 9295 | time 12[s] | loss 2.70
# | epoch 1 |  iter 481 / 9295 | time 12[s] | loss 2.69
# | epoch 1 |  iter 501 / 9295 | time 13[s] | loss 2.67
# | epoch 1 |  iter 521 / 9295 | time 13[s] | loss 2.67
# | epoch 1 |  iter 541 / 9295 | time 14[s] | loss 2.66
# | epoch 1 |  iter 561 / 9295 | time 15[s] | loss 2.64
# | epoch 1 |  iter 581 / 9295 | time 15[s] | loss 2.66
# | epoch 1 |  iter 601 / 9295 | time 16[s] | loss 2.63
# | epoch 1 |  iter 621 / 9295 | time 16[s] | loss 2.66
# | epoch 1 |  iter 641 / 9295 | time 17[s] | loss 2.63
# | epoch 1 |  iter 661 / 9295 | time 17[s] | loss 2.62
# | epoch 1 |  iter 681 / 9295 | time 18[s] | loss 2.65
# | epoch 1 |  iter 701 / 9295 | time 18[s] | loss 2.62
# | epoch 1 |  iter 721 / 9295 | time 19[s] | loss 2.60
# | epoch 1 |  iter 741 / 9295 | time 19[s] | loss 2.58
# | epoch 1 |  iter 761 / 9295 | time 20[s] | loss 2.58
# | epoch 1 |  iter 781 / 9295 | time 20[s] | loss 2.60
# | epoch 1 |  iter 801 / 9295 | time 21[s] | loss 2.57
# | epoch 1 |  iter 821 / 9295 | time 22[s] | loss 2.59
# | epoch 1 |  iter 841 / 9295 | time 22[s] | loss 2.61
# | epoch 1 |  iter 861 / 9295 | time 23[s] | loss 2.57
# | epoch 1 |  iter 881 / 9295 | time 23[s] | loss 2.58
# | epoch 1 |  iter 901 / 9295 | time 24[s] | loss 2.55
# | epoch 1 |  iter 921 / 9295 | time 24[s] | loss 2.56
# | epoch 1 |  iter 941 / 9295 | time 25[s] | loss 2.55
# | epoch 1 |  iter 961 / 9295 | time 25[s] | loss 2.57
# | epoch 1 |  iter 981 / 9295 | time 26[s] | loss 2.56
# | epoch 1 |  iter 1001 / 9295 | time 26[s] | loss 2.56
# | epoch 1 |  iter 1021 / 9295 | time 27[s] | loss 2.55
# | epoch 1 |  iter 1041 / 9295 | time 27[s] | loss 2.57
# | epoch 1 |  iter 1061 / 9295 | time 28[s] | loss 2.56
# | epoch 1 |  iter 1081 / 9295 | time 29[s] | loss 2.55
# | epoch 1 |  iter 1101 / 9295 | time 29[s] | loss 2.55
# | epoch 1 |  iter 1121 / 9295 | time 30[s] | loss 2.56
# | epoch 1 |  iter 1141 / 9295 | time 30[s] | loss 2.55
# | epoch 1 |  iter 1161 / 9295 | time 31[s] | loss 2.53
# | epoch 1 |  iter 1181 / 9295 | time 31[s] | loss 2.54
# | epoch 1 |  iter 1201 / 9295 | time 32[s] | loss 2.53
# | epoch 1 |  iter 1221 / 9295 | time 32[s] | loss 2.52
# | epoch 1 |  iter 1241 / 9295 | time 33[s] | loss 2.56
# | epoch 1 |  iter 1261 / 9295 | time 34[s] | loss 2.55
# | epoch 1 |  iter 1281 / 9295 | time 34[s] | loss 2.52
# | epoch 1 |  iter 1301 / 9295 | time 35[s] | loss 2.54
# | epoch 1 |  iter 1321 / 9295 | time 35[s] | loss 2.50
# | epoch 1 |  iter 1341 / 9295 | time 36[s] | loss 2.53
# | epoch 1 |  iter 1361 / 9295 | time 36[s] | loss 2.51
# | epoch 1 |  iter 1381 / 9295 | time 37[s] | loss 2.52
# | epoch 1 |  iter 1401 / 9295 | time 37[s] | loss 2.52
# | epoch 1 |  iter 1421 / 9295 | time 38[s] | loss 2.52
# | epoch 1 |  iter 1441 / 9295 | time 38[s] | loss 2.51
# | epoch 1 |  iter 1461 / 9295 | time 39[s] | loss 2.50
# | epoch 1 |  iter 1481 / 9295 | time 39[s] | loss 2.50
# | epoch 1 |  iter 1501 / 9295 | time 40[s] | loss 2.51
# | epoch 1 |  iter 1521 / 9295 | time 41[s] | loss 2.52
# | epoch 1 |  iter 1541 / 9295 | time 41[s] | loss 2.50
# | epoch 1 |  iter 1561 / 9295 | time 42[s] | loss 2.52
# | epoch 1 |  iter 1581 / 9295 | time 42[s] | loss 2.50
# | epoch 1 |  iter 1601 / 9295 | time 43[s] | loss 2.50
# | epoch 1 |  iter 1621 / 9295 | time 43[s] | loss 2.53
# | epoch 1 |  iter 1641 / 9295 | time 44[s] | loss 2.51
# | epoch 1 |  iter 1661 / 9295 | time 44[s] | loss 2.50
# | epoch 1 |  iter 1681 / 9295 | time 45[s] | loss 2.51
# | epoch 1 |  iter 1701 / 9295 | time 45[s] | loss 2.50
# | epoch 1 |  iter 1721 / 9295 | time 46[s] | loss 2.51
# | epoch 1 |  iter 1741 / 9295 | time 46[s] | loss 2.50
# | epoch 1 |  iter 1761 / 9295 | time 47[s] | loss 2.48
# | epoch 1 |  iter 1781 / 9295 | time 47[s] | loss 2.52
# | epoch 1 |  iter 1801 / 9295 | time 48[s] | loss 2.49
# | epoch 1 |  iter 1821 / 9295 | time 48[s] | loss 2.48
# | epoch 1 |  iter 1841 / 9295 | time 49[s] | loss 2.48
# | epoch 1 |  iter 1861 / 9295 | time 50[s] | loss 2.46
# | epoch 1 |  iter 1881 / 9295 | time 50[s] | loss 2.50
# | epoch 1 |  iter 1901 / 9295 | time 51[s] | loss 2.50
# | epoch 1 |  iter 1921 / 9295 | time 51[s] | loss 2.48
# | epoch 1 |  iter 1941 / 9295 | time 52[s] | loss 2.49
# | epoch 1 |  iter 1961 / 9295 | time 52[s] | loss 2.48
# | epoch 1 |  iter 1981 / 9295 | time 53[s] | loss 2.49
# | epoch 1 |  iter 2001 / 9295 | time 53[s] | loss 2.49
# | epoch 1 |  iter 2021 / 9295 | time 54[s] | loss 2.50
# | epoch 1 |  iter 2041 / 9295 | time 54[s] | loss 2.48
# | epoch 1 |  iter 2061 / 9295 | time 55[s] | loss 2.50
# | epoch 1 |  iter 2081 / 9295 | time 55[s] | loss 2.50
# | epoch 1 |  iter 2101 / 9295 | time 56[s] | loss 2.47
# | epoch 1 |  iter 2121 / 9295 | time 56[s] | loss 2.48
# | epoch 1 |  iter 2141 / 9295 | time 57[s] | loss 2.48
# | epoch 1 |  iter 2161 / 9295 | time 57[s] | loss 2.47
# | epoch 1 |  iter 2181 / 9295 | time 58[s] | loss 2.49
# | epoch 1 |  iter 2201 / 9295 | time 58[s] | loss 2.50
# | epoch 1 |  iter 2221 / 9295 | time 59[s] | loss 2.49
# | epoch 1 |  iter 2241 / 9295 | time 60[s] | loss 2.47
# | epoch 1 |  iter 2261 / 9295 | time 60[s] | loss 2.50
# | epoch 1 |  iter 2281 / 9295 | time 61[s] | loss 2.46
# | epoch 1 |  iter 2301 / 9295 | time 61[s] | loss 2.49
# | epoch 1 |  iter 2321 / 9295 | time 62[s] | loss 2.45
# | epoch 1 |  iter 2341 / 9295 | time 62[s] | loss 2.46
# | epoch 1 |  iter 2361 / 9295 | time 63[s] | loss 2.50
# | epoch 1 |  iter 2381 / 9295 | time 63[s] | loss 2.49
# | epoch 1 |  iter 2401 / 9295 | time 64[s] | loss 2.46
# | epoch 1 |  iter 2421 / 9295 | time 64[s] | loss 2.49
# | epoch 1 |  iter 2441 / 9295 | time 65[s] | loss 2.49
# | epoch 1 |  iter 2461 / 9295 | time 65[s] | loss 2.48
# | epoch 1 |  iter 2481 / 9295 | time 66[s] | loss 2.48
# | epoch 1 |  iter 2501 / 9295 | time 66[s] | loss 2.47
# | epoch 1 |  iter 2521 / 9295 | time 67[s] | loss 2.43
# | epoch 1 |  iter 2541 / 9295 | time 68[s] | loss 2.46
# | epoch 1 |  iter 2561 / 9295 | time 68[s] | loss 2.48
# | epoch 1 |  iter 2581 / 9295 | time 69[s] | loss 2.48
# | epoch 1 |  iter 2601 / 9295 | time 69[s] | loss 2.47
# | epoch 1 |  iter 2621 / 9295 | time 70[s] | loss 2.48
# | epoch 1 |  iter 2641 / 9295 | time 70[s] | loss 2.45
# | epoch 1 |  iter 2661 / 9295 | time 71[s] | loss 2.47
# | epoch 1 |  iter 2681 / 9295 | time 71[s] | loss 2.46
# | epoch 1 |  iter 2701 / 9295 | time 72[s] | loss 2.46
# | epoch 1 |  iter 2721 / 9295 | time 72[s] | loss 2.46
# | epoch 1 |  iter 2741 / 9295 | time 73[s] | loss 2.46
# | epoch 1 |  iter 2761 / 9295 | time 73[s] | loss 2.46
# | epoch 1 |  iter 2781 / 9295 | time 74[s] | loss 2.48
# | epoch 1 |  iter 2801 / 9295 | time 74[s] | loss 2.44
# | epoch 1 |  iter 2821 / 9295 | time 75[s] | loss 2.48
# | epoch 1 |  iter 2841 / 9295 | time 75[s] | loss 2.47
# | epoch 1 |  iter 2861 / 9295 | time 76[s] | loss 2.45
# | epoch 1 |  iter 2881 / 9295 | time 76[s] | loss 2.46
# | epoch 1 |  iter 2901 / 9295 | time 77[s] | loss 2.45
# | epoch 1 |  iter 2921 / 9295 | time 77[s] | loss 2.45
# | epoch 1 |  iter 2941 / 9295 | time 78[s] | loss 2.48
# | epoch 1 |  iter 2961 / 9295 | time 78[s] | loss 2.43
# | epoch 1 |  iter 2981 / 9295 | time 79[s] | loss 2.45
# | epoch 1 |  iter 3001 / 9295 | time 80[s] | loss 2.46
# | epoch 1 |  iter 3021 / 9295 | time 80[s] | loss 2.45
# | epoch 1 |  iter 3041 / 9295 | time 81[s] | loss 2.43
# | epoch 1 |  iter 3061 / 9295 | time 81[s] | loss 2.46
# | epoch 1 |  iter 3081 / 9295 | time 82[s] | loss 2.43
# | epoch 1 |  iter 3101 / 9295 | time 82[s] | loss 2.43
# | epoch 1 |  iter 3121 / 9295 | time 83[s] | loss 2.43
# | epoch 1 |  iter 3141 / 9295 | time 83[s] | loss 2.42
# | epoch 1 |  iter 3161 / 9295 | time 84[s] | loss 2.45
# | epoch 1 |  iter 3181 / 9295 | time 84[s] | loss 2.42
# | epoch 1 |  iter 3201 / 9295 | time 85[s] | loss 2.43
# | epoch 1 |  iter 3221 / 9295 | time 85[s] | loss 2.47
# | epoch 1 |  iter 3241 / 9295 | time 86[s] | loss 2.43
# | epoch 1 |  iter 3261 / 9295 | time 86[s] | loss 2.45
# | epoch 1 |  iter 3281 / 9295 | time 87[s] | loss 2.44
# | epoch 1 |  iter 3301 / 9295 | time 88[s] | loss 2.41
# | epoch 1 |  iter 3321 / 9295 | time 88[s] | loss 2.42
# | epoch 1 |  iter 3341 / 9295 | time 89[s] | loss 2.40
# | epoch 1 |  iter 3361 / 9295 | time 89[s] | loss 2.41
# | epoch 1 |  iter 3381 / 9295 | time 90[s] | loss 2.42
# | epoch 1 |  iter 3401 / 9295 | time 90[s] | loss 2.43
# | epoch 1 |  iter 3421 / 9295 | time 91[s] | loss 2.42
# | epoch 1 |  iter 3441 / 9295 | time 91[s] | loss 2.44
# | epoch 1 |  iter 3461 / 9295 | time 92[s] | loss 2.43
# | epoch 1 |  iter 3481 / 9295 | time 92[s] | loss 2.42
# | epoch 1 |  iter 3501 / 9295 | time 93[s] | loss 2.45
# | epoch 1 |  iter 3521 / 9295 | time 93[s] | loss 2.44
# | epoch 1 |  iter 3541 / 9295 | time 94[s] | loss 2.39
# | epoch 1 |  iter 3561 / 9295 | time 94[s] | loss 2.43
# | epoch 1 |  iter 3581 / 9295 | time 95[s] | loss 2.46
# | epoch 1 |  iter 3601 / 9295 | time 95[s] | loss 2.41
# | epoch 1 |  iter 3621 / 9295 | time 96[s] | loss 2.46
# | epoch 1 |  iter 3641 / 9295 | time 96[s] | loss 2.40
# | epoch 1 |  iter 3661 / 9295 | time 97[s] | loss 2.43
# | epoch 1 |  iter 3681 / 9295 | time 97[s] | loss 2.43
# | epoch 1 |  iter 3701 / 9295 | time 98[s] | loss 2.45
# | epoch 1 |  iter 3721 / 9295 | time 98[s] | loss 2.39
# | epoch 1 |  iter 3741 / 9295 | time 99[s] | loss 2.43
# | epoch 1 |  iter 3761 / 9295 | time 99[s] | loss 2.43
# | epoch 1 |  iter 3781 / 9295 | time 100[s] | loss 2.41
# | epoch 1 |  iter 3801 / 9295 | time 100[s] | loss 2.39
# | epoch 1 |  iter 3821 / 9295 | time 101[s] | loss 2.41
# | epoch 1 |  iter 3841 / 9295 | time 101[s] | loss 2.43
# | epoch 1 |  iter 3861 / 9295 | time 102[s] | loss 2.39
# | epoch 1 |  iter 3881 / 9295 | time 102[s] | loss 2.43
# | epoch 1 |  iter 3901 / 9295 | time 103[s] | loss 2.38
# | epoch 1 |  iter 3921 / 9295 | time 103[s] | loss 2.42
# | epoch 1 |  iter 3941 / 9295 | time 104[s] | loss 2.40
# | epoch 1 |  iter 3961 / 9295 | time 105[s] | loss 2.42
# | epoch 1 |  iter 3981 / 9295 | time 105[s] | loss 2.39
# | epoch 1 |  iter 4001 / 9295 | time 106[s] | loss 2.39
# | epoch 1 |  iter 4021 / 9295 | time 106[s] | loss 2.39
# | epoch 1 |  iter 4041 / 9295 | time 107[s] | loss 2.40
# | epoch 1 |  iter 4061 / 9295 | time 107[s] | loss 2.41
# | epoch 1 |  iter 4081 / 9295 | time 108[s] | loss 2.36
# | epoch 1 |  iter 4101 / 9295 | time 108[s] | loss 2.39
# | epoch 1 |  iter 4121 / 9295 | time 109[s] | loss 2.39
# | epoch 1 |  iter 4141 / 9295 | time 109[s] | loss 2.38
# | epoch 1 |  iter 4161 / 9295 | time 110[s] | loss 2.41
# | epoch 1 |  iter 4181 / 9295 | time 110[s] | loss 2.38
# | epoch 1 |  iter 4201 / 9295 | time 111[s] | loss 2.38
# | epoch 1 |  iter 4221 / 9295 | time 111[s] | loss 2.40
# | epoch 1 |  iter 4241 / 9295 | time 112[s] | loss 2.40
# | epoch 1 |  iter 4261 / 9295 | time 112[s] | loss 2.37
# | epoch 1 |  iter 4281 / 9295 | time 113[s] | loss 2.39
# | epoch 1 |  iter 4301 / 9295 | time 113[s] | loss 2.38
# | epoch 1 |  iter 4321 / 9295 | time 114[s] | loss 2.38
# | epoch 1 |  iter 4341 / 9295 | time 114[s] | loss 2.39
# | epoch 1 |  iter 4361 / 9295 | time 115[s] | loss 2.37
# | epoch 1 |  iter 4381 / 9295 | time 115[s] | loss 2.39
# | epoch 1 |  iter 4401 / 9295 | time 116[s] | loss 2.37
# | epoch 1 |  iter 4421 / 9295 | time 116[s] | loss 2.42
# | epoch 1 |  iter 4441 / 9295 | time 117[s] | loss 2.37
# | epoch 1 |  iter 4461 / 9295 | time 118[s] | loss 2.38
# | epoch 1 |  iter 4481 / 9295 | time 118[s] | loss 2.36
# | epoch 1 |  iter 4501 / 9295 | time 119[s] | loss 2.39
# | epoch 1 |  iter 4521 / 9295 | time 119[s] | loss 2.37
# | epoch 1 |  iter 4541 / 9295 | time 120[s] | loss 2.37
# | epoch 1 |  iter 4561 / 9295 | time 120[s] | loss 2.37
# | epoch 1 |  iter 4581 / 9295 | time 121[s] | loss 2.40
# | epoch 1 |  iter 4601 / 9295 | time 121[s] | loss 2.37
# | epoch 1 |  iter 4621 / 9295 | time 122[s] | loss 2.36
# | epoch 1 |  iter 4641 / 9295 | time 122[s] | loss 2.38
# | epoch 1 |  iter 4661 / 9295 | time 123[s] | loss 2.41
# | epoch 1 |  iter 4681 / 9295 | time 123[s] | loss 2.40
# | epoch 1 |  iter 4701 / 9295 | time 124[s] | loss 2.38
# | epoch 1 |  iter 4721 / 9295 | time 124[s] | loss 2.37
# | epoch 1 |  iter 4741 / 9295 | time 125[s] | loss 2.36
# | epoch 1 |  iter 4761 / 9295 | time 125[s] | loss 2.36
# | epoch 1 |  iter 4781 / 9295 | time 126[s] | loss 2.39
# | epoch 1 |  iter 4801 / 9295 | time 126[s] | loss 2.35
# | epoch 1 |  iter 4821 / 9295 | time 127[s] | loss 2.38
# | epoch 1 |  iter 4841 / 9295 | time 127[s] | loss 2.38
# | epoch 1 |  iter 4861 / 9295 | time 128[s] | loss 2.36
# | epoch 1 |  iter 4881 / 9295 | time 128[s] | loss 2.37
# | epoch 1 |  iter 4901 / 9295 | time 129[s] | loss 2.36
# | epoch 1 |  iter 4921 / 9295 | time 129[s] | loss 2.39
# | epoch 1 |  iter 4941 / 9295 | time 130[s] | loss 2.34
# | epoch 1 |  iter 4961 / 9295 | time 130[s] | loss 2.39
# | epoch 1 |  iter 4981 / 9295 | time 131[s] | loss 2.35
# | epoch 1 |  iter 5001 / 9295 | time 132[s] | loss 2.37
# | epoch 1 |  iter 5021 / 9295 | time 132[s] | loss 2.37
# | epoch 1 |  iter 5041 / 9295 | time 133[s] | loss 2.36
# | epoch 1 |  iter 5061 / 9295 | time 133[s] | loss 2.37
# | epoch 1 |  iter 5081 / 9295 | time 134[s] | loss 2.36
# | epoch 1 |  iter 5101 / 9295 | time 134[s] | loss 2.35
# | epoch 1 |  iter 5121 / 9295 | time 135[s] | loss 2.36
# | epoch 1 |  iter 5141 / 9295 | time 135[s] | loss 2.35
# | epoch 1 |  iter 5161 / 9295 | time 136[s] | loss 2.35
# | epoch 1 |  iter 5181 / 9295 | time 136[s] | loss 2.37
# | epoch 1 |  iter 5201 / 9295 | time 137[s] | loss 2.34
# | epoch 1 |  iter 5221 / 9295 | time 137[s] | loss 2.33
# | epoch 1 |  iter 5241 / 9295 | time 138[s] | loss 2.36
# | epoch 1 |  iter 5261 / 9295 | time 139[s] | loss 2.31
# | epoch 1 |  iter 5281 / 9295 | time 139[s] | loss 2.39
# | epoch 1 |  iter 5301 / 9295 | time 140[s] | loss 2.34
# | epoch 1 |  iter 5321 / 9295 | time 140[s] | loss 2.37
# | epoch 1 |  iter 5341 / 9295 | time 141[s] | loss 2.34
# | epoch 1 |  iter 5361 / 9295 | time 141[s] | loss 2.34
# | epoch 1 |  iter 5381 / 9295 | time 142[s] | loss 2.35
# | epoch 1 |  iter 5401 / 9295 | time 142[s] | loss 2.31
# | epoch 1 |  iter 5421 / 9295 | time 143[s] | loss 2.34
# | epoch 1 |  iter 5441 / 9295 | time 143[s] | loss 2.36
# | epoch 1 |  iter 5461 / 9295 | time 144[s] | loss 2.34
# | epoch 1 |  iter 5481 / 9295 | time 144[s] | loss 2.34
# | epoch 1 |  iter 5501 / 9295 | time 145[s] | loss 2.33
# | epoch 1 |  iter 5521 / 9295 | time 145[s] | loss 2.33
# | epoch 1 |  iter 5541 / 9295 | time 146[s] | loss 2.34
# | epoch 1 |  iter 5561 / 9295 | time 146[s] | loss 2.33
# | epoch 1 |  iter 5581 / 9295 | time 147[s] | loss 2.34
# | epoch 1 |  iter 5601 / 9295 | time 147[s] | loss 2.32
# | epoch 1 |  iter 5621 / 9295 | time 148[s] | loss 2.28
# | epoch 1 |  iter 5641 / 9295 | time 148[s] | loss 2.35
# | epoch 1 |  iter 5661 / 9295 | time 149[s] | loss 2.36
# | epoch 1 |  iter 5681 / 9295 | time 149[s] | loss 2.34
# | epoch 1 |  iter 5701 / 9295 | time 150[s] | loss 2.36
# | epoch 1 |  iter 5721 / 9295 | time 150[s] | loss 2.34
# | epoch 1 |  iter 5741 / 9295 | time 151[s] | loss 2.34
# | epoch 1 |  iter 5761 / 9295 | time 151[s] | loss 2.35
# | epoch 1 |  iter 5781 / 9295 | time 152[s] | loss 2.34
# | epoch 1 |  iter 5801 / 9295 | time 152[s] | loss 2.36
# | epoch 1 |  iter 5821 / 9295 | time 153[s] | loss 2.34
# | epoch 1 |  iter 5841 / 9295 | time 153[s] | loss 2.35
# | epoch 1 |  iter 5861 / 9295 | time 154[s] | loss 2.30
# | epoch 1 |  iter 5881 / 9295 | time 155[s] | loss 2.34
# | epoch 1 |  iter 5901 / 9295 | time 155[s] | loss 2.38
# | epoch 1 |  iter 5921 / 9295 | time 156[s] | loss 2.30
# | epoch 1 |  iter 5941 / 9295 | time 156[s] | loss 2.32
# | epoch 1 |  iter 5961 / 9295 | time 157[s] | loss 2.33
# | epoch 1 |  iter 5981 / 9295 | time 157[s] | loss 2.35
# | epoch 1 |  iter 6001 / 9295 | time 158[s] | loss 2.30
# | epoch 1 |  iter 6021 / 9295 | time 158[s] | loss 2.31
# | epoch 1 |  iter 6041 / 9295 | time 159[s] | loss 2.31
# | epoch 1 |  iter 6061 / 9295 | time 159[s] | loss 2.32
# | epoch 1 |  iter 6081 / 9295 | time 160[s] | loss 2.34
# | epoch 1 |  iter 6101 / 9295 | time 160[s] | loss 2.31
# | epoch 1 |  iter 6121 / 9295 | time 161[s] | loss 2.30
# | epoch 1 |  iter 6141 / 9295 | time 161[s] | loss 2.31
# | epoch 1 |  iter 6161 / 9295 | time 162[s] | loss 2.33
# | epoch 1 |  iter 6181 / 9295 | time 162[s] | loss 2.32
# | epoch 1 |  iter 6201 / 9295 | time 163[s] | loss 2.33
# | epoch 1 |  iter 6221 / 9295 | time 163[s] | loss 2.32
# | epoch 1 |  iter 6241 / 9295 | time 164[s] | loss 2.33
# | epoch 1 |  iter 6261 / 9295 | time 164[s] | loss 2.30
# | epoch 1 |  iter 6281 / 9295 | time 165[s] | loss 2.32
# | epoch 1 |  iter 6301 / 9295 | time 166[s] | loss 2.33
# | epoch 1 |  iter 6321 / 9295 | time 166[s] | loss 2.34
# | epoch 1 |  iter 6341 / 9295 | time 167[s] | loss 2.30
# | epoch 1 |  iter 6361 / 9295 | time 167[s] | loss 2.31
# | epoch 1 |  iter 6381 / 9295 | time 168[s] | loss 2.33
# | epoch 1 |  iter 6401 / 9295 | time 168[s] | loss 2.30
# | epoch 1 |  iter 6421 / 9295 | time 169[s] | loss 2.30
# | epoch 1 |  iter 6441 / 9295 | time 169[s] | loss 2.32
# | epoch 1 |  iter 6461 / 9295 | time 170[s] | loss 2.32
# | epoch 1 |  iter 6481 / 9295 | time 170[s] | loss 2.31
# | epoch 1 |  iter 6501 / 9295 | time 171[s] | loss 2.31
# | epoch 1 |  iter 6521 / 9295 | time 171[s] | loss 2.30
# | epoch 1 |  iter 6541 / 9295 | time 172[s] | loss 2.31
# | epoch 1 |  iter 6561 / 9295 | time 172[s] | loss 2.36
# | epoch 1 |  iter 6581 / 9295 | time 173[s] | loss 2.30
# | epoch 1 |  iter 6601 / 9295 | time 173[s] | loss 2.29
# | epoch 1 |  iter 6621 / 9295 | time 174[s] | loss 2.30
# | epoch 1 |  iter 6641 / 9295 | time 174[s] | loss 2.31
# | epoch 1 |  iter 6661 / 9295 | time 175[s] | loss 2.28
# | epoch 1 |  iter 6681 / 9295 | time 175[s] | loss 2.31
# | epoch 1 |  iter 6701 / 9295 | time 176[s] | loss 2.27
# | epoch 1 |  iter 6721 / 9295 | time 176[s] | loss 2.29
# | epoch 1 |  iter 6741 / 9295 | time 177[s] | loss 2.31
# | epoch 1 |  iter 6761 / 9295 | time 178[s] | loss 2.25
# | epoch 1 |  iter 6781 / 9295 | time 178[s] | loss 2.28
# | epoch 1 |  iter 6801 / 9295 | time 179[s] | loss 2.29
# | epoch 1 |  iter 6821 / 9295 | time 179[s] | loss 2.30
# | epoch 1 |  iter 6841 / 9295 | time 180[s] | loss 2.28
# | epoch 1 |  iter 6861 / 9295 | time 180[s] | loss 2.28
# | epoch 1 |  iter 6881 / 9295 | time 181[s] | loss 2.28
# | epoch 1 |  iter 6901 / 9295 | time 181[s] | loss 2.29
# | epoch 1 |  iter 6921 / 9295 | time 182[s] | loss 2.28
# | epoch 1 |  iter 6941 / 9295 | time 182[s] | loss 2.30
# | epoch 1 |  iter 6961 / 9295 | time 183[s] | loss 2.29
# | epoch 1 |  iter 6981 / 9295 | time 183[s] | loss 2.25
# | epoch 1 |  iter 7001 / 9295 | time 184[s] | loss 2.29
# | epoch 1 |  iter 7021 / 9295 | time 184[s] | loss 2.28
# | epoch 1 |  iter 7041 / 9295 | time 185[s] | loss 2.30
# | epoch 1 |  iter 7061 / 9295 | time 185[s] | loss 2.31
# | epoch 1 |  iter 7081 / 9295 | time 186[s] | loss 2.28
# | epoch 1 |  iter 7101 / 9295 | time 186[s] | loss 2.29
# | epoch 1 |  iter 7121 / 9295 | time 187[s] | loss 2.29
# | epoch 1 |  iter 7141 / 9295 | time 187[s] | loss 2.29
# | epoch 1 |  iter 7161 / 9295 | time 188[s] | loss 2.27
# | epoch 1 |  iter 7181 / 9295 | time 189[s] | loss 2.28
# | epoch 1 |  iter 7201 / 9295 | time 189[s] | loss 2.27
# | epoch 1 |  iter 7221 / 9295 | time 190[s] | loss 2.30
# | epoch 1 |  iter 7241 / 9295 | time 190[s] | loss 2.28
# | epoch 1 |  iter 7261 / 9295 | time 191[s] | loss 2.26
# | epoch 1 |  iter 7281 / 9295 | time 191[s] | loss 2.27
# | epoch 1 |  iter 7301 / 9295 | time 192[s] | loss 2.27
# | epoch 1 |  iter 7321 / 9295 | time 192[s] | loss 2.25
# | epoch 1 |  iter 7341 / 9295 | time 193[s] | loss 2.29
# | epoch 1 |  iter 7361 / 9295 | time 193[s] | loss 2.29
# | epoch 1 |  iter 7381 / 9295 | time 194[s] | loss 2.26
# | epoch 1 |  iter 7401 / 9295 | time 194[s] | loss 2.30
# | epoch 1 |  iter 7421 / 9295 | time 195[s] | loss 2.23
# | epoch 1 |  iter 7441 / 9295 | time 195[s] | loss 2.28
# | epoch 1 |  iter 7461 / 9295 | time 196[s] | loss 2.28
# | epoch 1 |  iter 7481 / 9295 | time 196[s] | loss 2.27
# | epoch 1 |  iter 7501 / 9295 | time 197[s] | loss 2.26
# | epoch 1 |  iter 7521 / 9295 | time 198[s] | loss 2.24
# | epoch 1 |  iter 7541 / 9295 | time 198[s] | loss 2.24
# | epoch 1 |  iter 7561 / 9295 | time 199[s] | loss 2.27
# | epoch 1 |  iter 7581 / 9295 | time 199[s] | loss 2.26
# | epoch 1 |  iter 7601 / 9295 | time 200[s] | loss 2.24
# | epoch 1 |  iter 7621 / 9295 | time 200[s] | loss 2.27
# | epoch 1 |  iter 7641 / 9295 | time 201[s] | loss 2.24
# | epoch 1 |  iter 7661 / 9295 | time 201[s] | loss 2.29
# | epoch 1 |  iter 7681 / 9295 | time 202[s] | loss 2.28
# | epoch 1 |  iter 7701 / 9295 | time 202[s] | loss 2.26
# | epoch 1 |  iter 7721 / 9295 | time 203[s] | loss 2.24
# | epoch 1 |  iter 7741 / 9295 | time 203[s] | loss 2.26
# | epoch 1 |  iter 7761 / 9295 | time 204[s] | loss 2.23
# | epoch 1 |  iter 7781 / 9295 | time 204[s] | loss 2.29
# | epoch 1 |  iter 7801 / 9295 | time 205[s] | loss 2.27
# | epoch 1 |  iter 7821 / 9295 | time 206[s] | loss 2.26
# | epoch 1 |  iter 7841 / 9295 | time 206[s] | loss 2.28
# | epoch 1 |  iter 7861 / 9295 | time 207[s] | loss 2.24
# | epoch 1 |  iter 7881 / 9295 | time 207[s] | loss 2.25
# | epoch 1 |  iter 7901 / 9295 | time 208[s] | loss 2.26
# | epoch 1 |  iter 7921 / 9295 | time 208[s] | loss 2.27
# | epoch 1 |  iter 7941 / 9295 | time 209[s] | loss 2.26
# | epoch 1 |  iter 7961 / 9295 | time 209[s] | loss 2.26
# | epoch 1 |  iter 7981 / 9295 | time 210[s] | loss 2.26
# | epoch 1 |  iter 8001 / 9295 | time 210[s] | loss 2.25
# | epoch 1 |  iter 8021 / 9295 | time 211[s] | loss 2.23
# | epoch 1 |  iter 8041 / 9295 | time 212[s] | loss 2.24
# | epoch 1 |  iter 8061 / 9295 | time 212[s] | loss 2.24
# | epoch 1 |  iter 8081 / 9295 | time 213[s] | loss 2.23
# | epoch 1 |  iter 8101 / 9295 | time 213[s] | loss 2.26
# | epoch 1 |  iter 8121 / 9295 | time 214[s] | loss 2.24
# | epoch 1 |  iter 8141 / 9295 | time 214[s] | loss 2.23
# | epoch 1 |  iter 8161 / 9295 | time 215[s] | loss 2.23
# | epoch 1 |  iter 8181 / 9295 | time 215[s] | loss 2.22
# | epoch 1 |  iter 8201 / 9295 | time 216[s] | loss 2.23
# | epoch 1 |  iter 8221 / 9295 | time 216[s] | loss 2.26
# | epoch 1 |  iter 8241 / 9295 | time 217[s] | loss 2.27
# | epoch 1 |  iter 8261 / 9295 | time 217[s] | loss 2.23
# | epoch 1 |  iter 8281 / 9295 | time 218[s] | loss 2.22
# | epoch 1 |  iter 8301 / 9295 | time 218[s] | loss 2.28
# | epoch 1 |  iter 8321 / 9295 | time 219[s] | loss 2.25
# | epoch 1 |  iter 8341 / 9295 | time 220[s] | loss 2.26
# | epoch 1 |  iter 8361 / 9295 | time 220[s] | loss 2.26
# | epoch 1 |  iter 8381 / 9295 | time 221[s] | loss 2.25
# | epoch 1 |  iter 8401 / 9295 | time 221[s] | loss 2.23
# | epoch 1 |  iter 8421 / 9295 | time 222[s] | loss 2.26
# | epoch 1 |  iter 8441 / 9295 | time 222[s] | loss 2.27
# | epoch 1 |  iter 8461 / 9295 | time 223[s] | loss 2.21
# | epoch 1 |  iter 8481 / 9295 | time 223[s] | loss 2.27
# | epoch 1 |  iter 8501 / 9295 | time 224[s] | loss 2.23
# | epoch 1 |  iter 8521 / 9295 | time 224[s] | loss 2.22
# | epoch 1 |  iter 8541 / 9295 | time 225[s] | loss 2.23
# | epoch 1 |  iter 8561 / 9295 | time 225[s] | loss 2.27
# | epoch 1 |  iter 8581 / 9295 | time 226[s] | loss 2.23
# | epoch 1 |  iter 8601 / 9295 | time 226[s] | loss 2.22
# | epoch 1 |  iter 8621 / 9295 | time 227[s] | loss 2.27
# | epoch 1 |  iter 8641 / 9295 | time 228[s] | loss 2.24
# | epoch 1 |  iter 8661 / 9295 | time 228[s] | loss 2.23
# | epoch 1 |  iter 8681 / 9295 | time 229[s] | loss 2.19
# | epoch 1 |  iter 8701 / 9295 | time 229[s] | loss 2.24
# | epoch 1 |  iter 8721 / 9295 | time 230[s] | loss 2.21
# | epoch 1 |  iter 8741 / 9295 | time 230[s] | loss 2.24
# | epoch 1 |  iter 8761 / 9295 | time 231[s] | loss 2.20
# | epoch 1 |  iter 8781 / 9295 | time 231[s] | loss 2.25
# | epoch 1 |  iter 8801 / 9295 | time 232[s] | loss 2.21
# | epoch 1 |  iter 8821 / 9295 | time 232[s] | loss 2.23
# | epoch 1 |  iter 8841 / 9295 | time 233[s] | loss 2.23
# | epoch 1 |  iter 8861 / 9295 | time 234[s] | loss 2.25
# | epoch 1 |  iter 8881 / 9295 | time 234[s] | loss 2.23
# | epoch 1 |  iter 8901 / 9295 | time 235[s] | loss 2.21
# | epoch 1 |  iter 8921 / 9295 | time 235[s] | loss 2.22
# | epoch 1 |  iter 8941 / 9295 | time 236[s] | loss 2.24
# | epoch 1 |  iter 8961 / 9295 | time 236[s] | loss 2.23
# | epoch 1 |  iter 8981 / 9295 | time 237[s] | loss 2.22
# | epoch 1 |  iter 9001 / 9295 | time 237[s] | loss 2.22
# | epoch 1 |  iter 9021 / 9295 | time 238[s] | loss 2.20
# | epoch 1 |  iter 9041 / 9295 | time 238[s] | loss 2.21
# | epoch 1 |  iter 9061 / 9295 | time 239[s] | loss 2.21
# | epoch 1 |  iter 9081 / 9295 | time 239[s] | loss 2.23
# | epoch 1 |  iter 9101 / 9295 | time 240[s] | loss 2.21
# | epoch 1 |  iter 9121 / 9295 | time 240[s] | loss 2.22
# | epoch 1 |  iter 9141 / 9295 | time 241[s] | loss 2.24
# | epoch 1 |  iter 9161 / 9295 | time 241[s] | loss 2.25
# | epoch 1 |  iter 9181 / 9295 | time 242[s] | loss 2.25
# | epoch 1 |  iter 9201 / 9295 | time 243[s] | loss 2.23
# | epoch 1 |  iter 9221 / 9295 | time 243[s] | loss 2.22
# | epoch 1 |  iter 9241 / 9295 | time 244[s] | loss 2.24
# | epoch 1 |  iter 9261 / 9295 | time 244[s] | loss 2.20
# | epoch 1 |  iter 9281 / 9295 | time 245[s] | loss 2.23
# | epoch 2 |  iter 1 / 9295 | time 245[s] | loss 2.24
# | epoch 2 |  iter 21 / 9295 | time 246[s] | loss 2.18
# | epoch 2 |  iter 41 / 9295 | time 246[s] | loss 2.19
# | epoch 2 |  iter 61 / 9295 | time 247[s] | loss 2.19
# | epoch 2 |  iter 81 / 9295 | time 247[s] | loss 2.18
# | epoch 2 |  iter 101 / 9295 | time 248[s] | loss 2.17
# | epoch 2 |  iter 121 / 9295 | time 248[s] | loss 2.18
# | epoch 2 |  iter 141 / 9295 | time 249[s] | loss 2.17
# | epoch 2 |  iter 161 / 9295 | time 249[s] | loss 2.22
# | epoch 2 |  iter 181 / 9295 | time 250[s] | loss 2.19
# | epoch 2 |  iter 201 / 9295 | time 250[s] | loss 2.16
# | epoch 2 |  iter 221 / 9295 | time 251[s] | loss 2.18
# | epoch 2 |  iter 241 / 9295 | time 252[s] | loss 2.17
# | epoch 2 |  iter 261 / 9295 | time 252[s] | loss 2.15
# | epoch 2 |  iter 281 / 9295 | time 253[s] | loss 2.18
# | epoch 2 |  iter 301 / 9295 | time 253[s] | loss 2.21
# | epoch 2 |  iter 321 / 9295 | time 254[s] | loss 2.20
# | epoch 2 |  iter 341 / 9295 | time 254[s] | loss 2.21
# | epoch 2 |  iter 361 / 9295 | time 255[s] | loss 2.19
# | epoch 2 |  iter 381 / 9295 | time 255[s] | loss 2.19
# | epoch 2 |  iter 401 / 9295 | time 256[s] | loss 2.14
# | epoch 2 |  iter 421 / 9295 | time 256[s] | loss 2.15
# | epoch 2 |  iter 441 / 9295 | time 257[s] | loss 2.18
# | epoch 2 |  iter 461 / 9295 | time 257[s] | loss 2.15
# | epoch 2 |  iter 481 / 9295 | time 258[s] | loss 2.17
# | epoch 2 |  iter 501 / 9295 | time 258[s] | loss 2.18
# | epoch 2 |  iter 521 / 9295 | time 259[s] | loss 2.18
# | epoch 2 |  iter 541 / 9295 | time 259[s] | loss 2.16
# | epoch 2 |  iter 561 / 9295 | time 260[s] | loss 2.19
# | epoch 2 |  iter 581 / 9295 | time 261[s] | loss 2.17
# | epoch 2 |  iter 601 / 9295 | time 261[s] | loss 2.18
# | epoch 2 |  iter 621 / 9295 | time 262[s] | loss 2.16
# | epoch 2 |  iter 641 / 9295 | time 262[s] | loss 2.17
# | epoch 2 |  iter 661 / 9295 | time 263[s] | loss 2.17
# | epoch 2 |  iter 681 / 9295 | time 263[s] | loss 2.17
# | epoch 2 |  iter 701 / 9295 | time 264[s] | loss 2.16
# | epoch 2 |  iter 721 / 9295 | time 264[s] | loss 2.15
# | epoch 2 |  iter 741 / 9295 | time 265[s] | loss 2.17
# | epoch 2 |  iter 761 / 9295 | time 265[s] | loss 2.11
# | epoch 2 |  iter 781 / 9295 | time 266[s] | loss 2.14
# | epoch 2 |  iter 801 / 9295 | time 266[s] | loss 2.13
# | epoch 2 |  iter 821 / 9295 | time 267[s] | loss 2.17
# | epoch 2 |  iter 841 / 9295 | time 268[s] | loss 2.19
# | epoch 2 |  iter 861 / 9295 | time 268[s] | loss 2.17
# | epoch 2 |  iter 881 / 9295 | time 269[s] | loss 2.17
# | epoch 2 |  iter 901 / 9295 | time 269[s] | loss 2.20
# | epoch 2 |  iter 921 / 9295 | time 270[s] | loss 2.17
# | epoch 2 |  iter 941 / 9295 | time 270[s] | loss 2.16
# | epoch 2 |  iter 961 / 9295 | time 271[s] | loss 2.15
# | epoch 2 |  iter 981 / 9295 | time 271[s] | loss 2.15
# | epoch 2 |  iter 1001 / 9295 | time 272[s] | loss 2.16
# | epoch 2 |  iter 1021 / 9295 | time 272[s] | loss 2.15
# | epoch 2 |  iter 1041 / 9295 | time 273[s] | loss 2.16
# | epoch 2 |  iter 1061 / 9295 | time 273[s] | loss 2.18
# | epoch 2 |  iter 1081 / 9295 | time 274[s] | loss 2.12
# | epoch 2 |  iter 1101 / 9295 | time 274[s] | loss 2.16
# | epoch 2 |  iter 1121 / 9295 | time 275[s] | loss 2.17
# | epoch 2 |  iter 1141 / 9295 | time 275[s] | loss 2.16
# | epoch 2 |  iter 1161 / 9295 | time 276[s] | loss 2.18
# | epoch 2 |  iter 1181 / 9295 | time 276[s] | loss 2.15
# | epoch 2 |  iter 1201 / 9295 | time 277[s] | loss 2.18
# | epoch 2 |  iter 1221 / 9295 | time 278[s] | loss 2.14
# | epoch 2 |  iter 1241 / 9295 | time 278[s] | loss 2.18
# | epoch 2 |  iter 1261 / 9295 | time 279[s] | loss 2.19
# | epoch 2 |  iter 1281 / 9295 | time 279[s] | loss 2.17
# | epoch 2 |  iter 1301 / 9295 | time 280[s] | loss 2.18
# | epoch 2 |  iter 1321 / 9295 | time 280[s] | loss 2.14
# | epoch 2 |  iter 1341 / 9295 | time 281[s] | loss 2.15
# | epoch 2 |  iter 1361 / 9295 | time 281[s] | loss 2.13
# | epoch 2 |  iter 1381 / 9295 | time 282[s] | loss 2.13
# | epoch 2 |  iter 1401 / 9295 | time 282[s] | loss 2.17
# | epoch 2 |  iter 1421 / 9295 | time 283[s] | loss 2.16
# | epoch 2 |  iter 1441 / 9295 | time 283[s] | loss 2.14
# | epoch 2 |  iter 1461 / 9295 | time 284[s] | loss 2.16
# | epoch 2 |  iter 1481 / 9295 | time 284[s] | loss 2.14
# | epoch 2 |  iter 1501 / 9295 | time 285[s] | loss 2.14
# | epoch 2 |  iter 1521 / 9295 | time 285[s] | loss 2.14
# | epoch 2 |  iter 1541 / 9295 | time 286[s] | loss 2.16
# | epoch 2 |  iter 1561 / 9295 | time 287[s] | loss 2.18
# | epoch 2 |  iter 1581 / 9295 | time 287[s] | loss 2.14
# | epoch 2 |  iter 1601 / 9295 | time 288[s] | loss 2.15
# | epoch 2 |  iter 1621 / 9295 | time 288[s] | loss 2.12
# | epoch 2 |  iter 1641 / 9295 | time 289[s] | loss 2.16
# | epoch 2 |  iter 1661 / 9295 | time 289[s] | loss 2.14
# | epoch 2 |  iter 1681 / 9295 | time 290[s] | loss 2.17
# | epoch 2 |  iter 1701 / 9295 | time 290[s] | loss 2.16
# | epoch 2 |  iter 1721 / 9295 | time 291[s] | loss 2.12
# | epoch 2 |  iter 1741 / 9295 | time 291[s] | loss 2.16
# | epoch 2 |  iter 1761 / 9295 | time 292[s] | loss 2.12
# | epoch 2 |  iter 1781 / 9295 | time 292[s] | loss 2.16
# | epoch 2 |  iter 1801 / 9295 | time 293[s] | loss 2.14
# | epoch 2 |  iter 1821 / 9295 | time 293[s] | loss 2.14
# | epoch 2 |  iter 1841 / 9295 | time 294[s] | loss 2.13
# | epoch 2 |  iter 1861 / 9295 | time 295[s] | loss 2.16
# | epoch 2 |  iter 1881 / 9295 | time 295[s] | loss 2.15
# | epoch 2 |  iter 1901 / 9295 | time 296[s] | loss 2.16
# | epoch 2 |  iter 1921 / 9295 | time 296[s] | loss 2.16
# | epoch 2 |  iter 1941 / 9295 | time 297[s] | loss 2.19
# | epoch 2 |  iter 1961 / 9295 | time 297[s] | loss 2.13
# | epoch 2 |  iter 1981 / 9295 | time 298[s] | loss 2.16
# | epoch 2 |  iter 2001 / 9295 | time 298[s] | loss 2.12
# | epoch 2 |  iter 2021 / 9295 | time 299[s] | loss 2.17
# | epoch 2 |  iter 2041 / 9295 | time 299[s] | loss 2.12
# | epoch 2 |  iter 2061 / 9295 | time 300[s] | loss 2.14
# | epoch 2 |  iter 2081 / 9295 | time 300[s] | loss 2.11
# | epoch 2 |  iter 2101 / 9295 | time 301[s] | loss 2.11
# | epoch 2 |  iter 2121 / 9295 | time 301[s] | loss 2.14
# | epoch 2 |  iter 2141 / 9295 | time 302[s] | loss 2.13
# | epoch 2 |  iter 2161 / 9295 | time 303[s] | loss 2.13
# | epoch 2 |  iter 2181 / 9295 | time 303[s] | loss 2.14
# | epoch 2 |  iter 2201 / 9295 | time 304[s] | loss 2.12
# | epoch 2 |  iter 2221 / 9295 | time 304[s] | loss 2.15
# | epoch 2 |  iter 2241 / 9295 | time 305[s] | loss 2.15
# | epoch 2 |  iter 2261 / 9295 | time 305[s] | loss 2.11
# | epoch 2 |  iter 2281 / 9295 | time 306[s] | loss 2.11
# | epoch 2 |  iter 2301 / 9295 | time 306[s] | loss 2.14
# | epoch 2 |  iter 2321 / 9295 | time 307[s] | loss 2.17
# | epoch 2 |  iter 2341 / 9295 | time 307[s] | loss 2.13
# | epoch 2 |  iter 2361 / 9295 | time 308[s] | loss 2.16
# | epoch 2 |  iter 2381 / 9295 | time 308[s] | loss 2.15
# | epoch 2 |  iter 2401 / 9295 | time 309[s] | loss 2.14
# | epoch 2 |  iter 2421 / 9295 | time 309[s] | loss 2.16
# | epoch 2 |  iter 2441 / 9295 | time 310[s] | loss 2.15
# | epoch 2 |  iter 2461 / 9295 | time 311[s] | loss 2.15
# | epoch 2 |  iter 2481 / 9295 | time 311[s] | loss 2.17
# | epoch 2 |  iter 2501 / 9295 | time 312[s] | loss 2.14
# | epoch 2 |  iter 2521 / 9295 | time 312[s] | loss 2.16
# | epoch 2 |  iter 2541 / 9295 | time 313[s] | loss 2.16
# | epoch 2 |  iter 2561 / 9295 | time 313[s] | loss 2.13
# | epoch 2 |  iter 2581 / 9295 | time 314[s] | loss 2.13
# | epoch 2 |  iter 2601 / 9295 | time 315[s] | loss 2.12
# | epoch 2 |  iter 2621 / 9295 | time 315[s] | loss 2.11
# | epoch 2 |  iter 2641 / 9295 | time 316[s] | loss 2.15
# | epoch 2 |  iter 2661 / 9295 | time 316[s] | loss 2.10
# | epoch 2 |  iter 2681 / 9295 | time 317[s] | loss 2.15
# | epoch 2 |  iter 2701 / 9295 | time 317[s] | loss 2.11
# | epoch 2 |  iter 2721 / 9295 | time 318[s] | loss 2.12
# | epoch 2 |  iter 2741 / 9295 | time 318[s] | loss 2.11
# | epoch 2 |  iter 2761 / 9295 | time 319[s] | loss 2.14
# | epoch 2 |  iter 2781 / 9295 | time 319[s] | loss 2.13
# | epoch 2 |  iter 2801 / 9295 | time 320[s] | loss 2.10
# | epoch 2 |  iter 2821 / 9295 | time 320[s] | loss 2.14
# | epoch 2 |  iter 2841 / 9295 | time 321[s] | loss 2.11
# | epoch 2 |  iter 2861 / 9295 | time 322[s] | loss 2.13
# | epoch 2 |  iter 2881 / 9295 | time 322[s] | loss 2.13
# | epoch 2 |  iter 2901 / 9295 | time 323[s] | loss 2.14
# | epoch 2 |  iter 2921 / 9295 | time 323[s] | loss 2.12
# | epoch 2 |  iter 2941 / 9295 | time 324[s] | loss 2.16
# | epoch 2 |  iter 2961 / 9295 | time 324[s] | loss 2.11
# | epoch 2 |  iter 2981 / 9295 | time 325[s] | loss 2.11
# | epoch 2 |  iter 3001 / 9295 | time 325[s] | loss 2.15
# | epoch 2 |  iter 3021 / 9295 | time 326[s] | loss 2.10
# | epoch 2 |  iter 3041 / 9295 | time 327[s] | loss 2.12
# | epoch 2 |  iter 3061 / 9295 | time 327[s] | loss 2.12
# | epoch 2 |  iter 3081 / 9295 | time 328[s] | loss 2.14
# | epoch 2 |  iter 3101 / 9295 | time 328[s] | loss 2.10
# | epoch 2 |  iter 3121 / 9295 | time 329[s] | loss 2.12
# | epoch 2 |  iter 3141 / 9295 | time 329[s] | loss 2.10
# | epoch 2 |  iter 3161 / 9295 | time 330[s] | loss 2.11
# | epoch 2 |  iter 3181 / 9295 | time 330[s] | loss 2.12
# | epoch 2 |  iter 3201 / 9295 | time 331[s] | loss 2.09
# | epoch 2 |  iter 3221 / 9295 | time 331[s] | loss 2.12
# | epoch 2 |  iter 3241 / 9295 | time 332[s] | loss 2.13
# | epoch 2 |  iter 3261 / 9295 | time 332[s] | loss 2.14
# | epoch 2 |  iter 3281 / 9295 | time 333[s] | loss 2.13
# | epoch 2 |  iter 3301 / 9295 | time 333[s] | loss 2.13
# | epoch 2 |  iter 3321 / 9295 | time 334[s] | loss 2.12
# | epoch 2 |  iter 3341 / 9295 | time 334[s] | loss 2.09
# | epoch 2 |  iter 3361 / 9295 | time 335[s] | loss 2.11
# | epoch 2 |  iter 3381 / 9295 | time 335[s] | loss 2.07
# | epoch 2 |  iter 3401 / 9295 | time 336[s] | loss 2.11
# | epoch 2 |  iter 3421 / 9295 | time 336[s] | loss 2.07
# | epoch 2 |  iter 3441 / 9295 | time 337[s] | loss 2.14
# | epoch 2 |  iter 3461 / 9295 | time 338[s] | loss 2.11
# | epoch 2 |  iter 3481 / 9295 | time 338[s] | loss 2.11
# | epoch 2 |  iter 3501 / 9295 | time 339[s] | loss 2.14
# | epoch 2 |  iter 3521 / 9295 | time 339[s] | loss 2.11
# | epoch 2 |  iter 3541 / 9295 | time 340[s] | loss 2.10
# | epoch 2 |  iter 3561 / 9295 | time 340[s] | loss 2.14
# | epoch 2 |  iter 3581 / 9295 | time 341[s] | loss 2.10
# | epoch 2 |  iter 3601 / 9295 | time 341[s] | loss 2.12
# | epoch 2 |  iter 3621 / 9295 | time 342[s] | loss 2.13
# | epoch 2 |  iter 3641 / 9295 | time 343[s] | loss 2.11
# | epoch 2 |  iter 3661 / 9295 | time 343[s] | loss 2.09
# | epoch 2 |  iter 3681 / 9295 | time 344[s] | loss 2.10
# | epoch 2 |  iter 3701 / 9295 | time 344[s] | loss 2.08
# | epoch 2 |  iter 3721 / 9295 | time 345[s] | loss 2.10
# | epoch 2 |  iter 3741 / 9295 | time 345[s] | loss 2.09
# | epoch 2 |  iter 3761 / 9295 | time 346[s] | loss 2.09
# | epoch 2 |  iter 3781 / 9295 | time 346[s] | loss 2.11
# | epoch 2 |  iter 3801 / 9295 | time 347[s] | loss 2.11
# | epoch 2 |  iter 3821 / 9295 | time 347[s] | loss 2.10
# | epoch 2 |  iter 3841 / 9295 | time 348[s] | loss 2.12
# | epoch 2 |  iter 3861 / 9295 | time 348[s] | loss 2.09
# | epoch 2 |  iter 3881 / 9295 | time 349[s] | loss 2.13
# | epoch 2 |  iter 3901 / 9295 | time 350[s] | loss 2.13
# | epoch 2 |  iter 3921 / 9295 | time 350[s] | loss 2.04
# | epoch 2 |  iter 3941 / 9295 | time 351[s] | loss 2.12
# | epoch 2 |  iter 3961 / 9295 | time 351[s] | loss 2.11
# | epoch 2 |  iter 3981 / 9295 | time 352[s] | loss 2.08
# | epoch 2 |  iter 4001 / 9295 | time 352[s] | loss 2.12
# | epoch 2 |  iter 4021 / 9295 | time 353[s] | loss 2.07
# | epoch 2 |  iter 4041 / 9295 | time 353[s] | loss 2.11
# | epoch 2 |  iter 4061 / 9295 | time 354[s] | loss 2.10
# | epoch 2 |  iter 4081 / 9295 | time 354[s] | loss 2.12
# | epoch 2 |  iter 4101 / 9295 | time 355[s] | loss 2.11
# | epoch 2 |  iter 4121 / 9295 | time 355[s] | loss 2.08
# | epoch 2 |  iter 4141 / 9295 | time 356[s] | loss 2.10
# | epoch 2 |  iter 4161 / 9295 | time 356[s] | loss 2.09
# | epoch 2 |  iter 4181 / 9295 | time 357[s] | loss 2.10
# | epoch 2 |  iter 4201 / 9295 | time 357[s] | loss 2.09
# | epoch 2 |  iter 4221 / 9295 | time 358[s] | loss 2.05
# | epoch 2 |  iter 4241 / 9295 | time 358[s] | loss 2.11
# | epoch 2 |  iter 4261 / 9295 | time 359[s] | loss 2.11
# | epoch 2 |  iter 4281 / 9295 | time 360[s] | loss 2.10
# | epoch 2 |  iter 4301 / 9295 | time 360[s] | loss 2.07
# | epoch 2 |  iter 4321 / 9295 | time 361[s] | loss 2.12
# | epoch 2 |  iter 4341 / 9295 | time 361[s] | loss 2.11
# | epoch 2 |  iter 4361 / 9295 | time 362[s] | loss 2.07
# | epoch 2 |  iter 4381 / 9295 | time 362[s] | loss 2.08
# | epoch 2 |  iter 4401 / 9295 | time 363[s] | loss 2.10
# | epoch 2 |  iter 4421 / 9295 | time 364[s] | loss 2.11
# | epoch 2 |  iter 4441 / 9295 | time 364[s] | loss 2.10
# | epoch 2 |  iter 4461 / 9295 | time 365[s] | loss 2.11
# | epoch 2 |  iter 4481 / 9295 | time 365[s] | loss 2.09
# | epoch 2 |  iter 4501 / 9295 | time 366[s] | loss 2.08
# | epoch 2 |  iter 4521 / 9295 | time 366[s] | loss 2.09
# | epoch 2 |  iter 4541 / 9295 | time 367[s] | loss 2.12
# | epoch 2 |  iter 4561 / 9295 | time 367[s] | loss 2.08
# | epoch 2 |  iter 4581 / 9295 | time 368[s] | loss 2.12
# | epoch 2 |  iter 4601 / 9295 | time 368[s] | loss 2.10
# | epoch 2 |  iter 4621 / 9295 | time 369[s] | loss 2.10
# | epoch 2 |  iter 4641 / 9295 | time 369[s] | loss 2.11
# | epoch 2 |  iter 4661 / 9295 | time 370[s] | loss 2.07
# | epoch 2 |  iter 4681 / 9295 | time 370[s] | loss 2.12
# | epoch 2 |  iter 4701 / 9295 | time 371[s] | loss 2.12
# | epoch 2 |  iter 4721 / 9295 | time 371[s] | loss 2.06
# | epoch 2 |  iter 4741 / 9295 | time 372[s] | loss 2.10
# | epoch 2 |  iter 4761 / 9295 | time 372[s] | loss 2.11
# | epoch 2 |  iter 4781 / 9295 | time 373[s] | loss 2.09
# | epoch 2 |  iter 4801 / 9295 | time 373[s] | loss 2.10
# | epoch 2 |  iter 4821 / 9295 | time 374[s] | loss 2.08
# | epoch 2 |  iter 4841 / 9295 | time 374[s] | loss 2.07
# | epoch 2 |  iter 4861 / 9295 | time 375[s] | loss 2.09
# | epoch 2 |  iter 4881 / 9295 | time 375[s] | loss 2.11
# | epoch 2 |  iter 4901 / 9295 | time 376[s] | loss 2.07
# | epoch 2 |  iter 4921 / 9295 | time 377[s] | loss 2.08
# | epoch 2 |  iter 4941 / 9295 | time 377[s] | loss 2.05
# | epoch 2 |  iter 4961 / 9295 | time 378[s] | loss 2.10
# | epoch 2 |  iter 4981 / 9295 | time 378[s] | loss 2.06
# | epoch 2 |  iter 5001 / 9295 | time 379[s] | loss 2.10
# | epoch 2 |  iter 5021 / 9295 | time 379[s] | loss 2.03
# | epoch 2 |  iter 5041 / 9295 | time 380[s] | loss 2.13
# | epoch 2 |  iter 5061 / 9295 | time 380[s] | loss 2.06
# | epoch 2 |  iter 5081 / 9295 | time 381[s] | loss 2.07
# | epoch 2 |  iter 5101 / 9295 | time 381[s] | loss 2.10
# | epoch 2 |  iter 5121 / 9295 | time 382[s] | loss 2.08
# | epoch 2 |  iter 5141 / 9295 | time 382[s] | loss 2.10
# | epoch 2 |  iter 5161 / 9295 | time 383[s] | loss 2.08
# | epoch 2 |  iter 5181 / 9295 | time 383[s] | loss 2.06
# | epoch 2 |  iter 5201 / 9295 | time 384[s] | loss 2.09
# | epoch 2 |  iter 5221 / 9295 | time 384[s] | loss 2.11
# | epoch 2 |  iter 5241 / 9295 | time 385[s] | loss 2.03
# | epoch 2 |  iter 5261 / 9295 | time 386[s] | loss 2.11
# | epoch 2 |  iter 5281 / 9295 | time 386[s] | loss 2.04
# | epoch 2 |  iter 5301 / 9295 | time 387[s] | loss 2.07
# | epoch 2 |  iter 5321 / 9295 | time 387[s] | loss 2.09
# | epoch 2 |  iter 5341 / 9295 | time 388[s] | loss 2.06
# | epoch 2 |  iter 5361 / 9295 | time 388[s] | loss 2.09
# | epoch 2 |  iter 5381 / 9295 | time 389[s] | loss 2.07
# | epoch 2 |  iter 5401 / 9295 | time 389[s] | loss 2.07
# | epoch 2 |  iter 5421 / 9295 | time 390[s] | loss 2.09
# | epoch 2 |  iter 5441 / 9295 | time 390[s] | loss 2.09
# | epoch 2 |  iter 5461 / 9295 | time 391[s] | loss 2.12
# | epoch 2 |  iter 5481 / 9295 | time 391[s] | loss 2.07
# | epoch 2 |  iter 5501 / 9295 | time 392[s] | loss 2.06
# | epoch 2 |  iter 5521 / 9295 | time 392[s] | loss 2.06
# | epoch 2 |  iter 5541 / 9295 | time 393[s] | loss 2.05
# | epoch 2 |  iter 5561 / 9295 | time 394[s] | loss 2.07
# | epoch 2 |  iter 5581 / 9295 | time 394[s] | loss 2.08
# | epoch 2 |  iter 5601 / 9295 | time 395[s] | loss 2.08
# | epoch 2 |  iter 5621 / 9295 | time 395[s] | loss 2.05
# | epoch 2 |  iter 5641 / 9295 | time 396[s] | loss 2.10
# | epoch 2 |  iter 5661 / 9295 | time 396[s] | loss 2.05
# | epoch 2 |  iter 5681 / 9295 | time 397[s] | loss 2.05
# | epoch 2 |  iter 5701 / 9295 | time 397[s] | loss 2.04
# | epoch 2 |  iter 5721 / 9295 | time 398[s] | loss 2.06
# | epoch 2 |  iter 5741 / 9295 | time 398[s] | loss 2.05
# | epoch 2 |  iter 5761 / 9295 | time 399[s] | loss 2.07
# | epoch 2 |  iter 5781 / 9295 | time 399[s] | loss 2.07
# | epoch 2 |  iter 5801 / 9295 | time 400[s] | loss 2.04
# | epoch 2 |  iter 5821 / 9295 | time 400[s] | loss 2.06
# | epoch 2 |  iter 5841 / 9295 | time 401[s] | loss 2.05
# | epoch 2 |  iter 5861 / 9295 | time 401[s] | loss 2.09
# | epoch 2 |  iter 5881 / 9295 | time 402[s] | loss 2.04
# | epoch 2 |  iter 5901 / 9295 | time 402[s] | loss 2.04
# | epoch 2 |  iter 5921 / 9295 | time 403[s] | loss 2.07
# | epoch 2 |  iter 5941 / 9295 | time 403[s] | loss 2.09
# | epoch 2 |  iter 5961 / 9295 | time 404[s] | loss 2.04
# | epoch 2 |  iter 5981 / 9295 | time 404[s] | loss 2.04
# | epoch 2 |  iter 6001 / 9295 | time 405[s] | loss 2.05
# | epoch 2 |  iter 6021 / 9295 | time 405[s] | loss 2.06
# | epoch 2 |  iter 6041 / 9295 | time 406[s] | loss 2.07
# | epoch 2 |  iter 6061 / 9295 | time 406[s] | loss 2.04
# | epoch 2 |  iter 6081 / 9295 | time 407[s] | loss 2.09
# | epoch 2 |  iter 6101 / 9295 | time 407[s] | loss 2.08
# | epoch 2 |  iter 6121 / 9295 | time 408[s] | loss 2.03
# | epoch 2 |  iter 6141 / 9295 | time 408[s] | loss 2.05
# | epoch 2 |  iter 6161 / 9295 | time 409[s] | loss 2.06
# | epoch 2 |  iter 6181 / 9295 | time 409[s] | loss 2.03
# | epoch 2 |  iter 6201 / 9295 | time 410[s] | loss 2.04
# | epoch 2 |  iter 6221 / 9295 | time 410[s] | loss 2.03
# | epoch 2 |  iter 6241 / 9295 | time 411[s] | loss 2.05
# | epoch 2 |  iter 6261 / 9295 | time 411[s] | loss 2.05
# | epoch 2 |  iter 6281 / 9295 | time 412[s] | loss 2.03
# | epoch 2 |  iter 6301 / 9295 | time 413[s] | loss 2.07
# | epoch 2 |  iter 6321 / 9295 | time 413[s] | loss 2.05
# | epoch 2 |  iter 6341 / 9295 | time 414[s] | loss 2.09
# | epoch 2 |  iter 6361 / 9295 | time 414[s] | loss 2.03
# | epoch 2 |  iter 6381 / 9295 | time 415[s] | loss 2.06
# | epoch 2 |  iter 6401 / 9295 | time 415[s] | loss 2.03
# | epoch 2 |  iter 6421 / 9295 | time 416[s] | loss 2.06
# | epoch 2 |  iter 6441 / 9295 | time 416[s] | loss 2.06
# | epoch 2 |  iter 6461 / 9295 | time 417[s] | loss 2.04
# | epoch 2 |  iter 6481 / 9295 | time 417[s] | loss 2.06
# | epoch 2 |  iter 6501 / 9295 | time 418[s] | loss 2.07
# | epoch 2 |  iter 6521 / 9295 | time 418[s] | loss 2.03
# | epoch 2 |  iter 6541 / 9295 | time 419[s] | loss 2.05
# | epoch 2 |  iter 6561 / 9295 | time 419[s] | loss 2.07
# | epoch 2 |  iter 6581 / 9295 | time 420[s] | loss 2.09
# | epoch 2 |  iter 6601 / 9295 | time 421[s] | loss 2.08
# | epoch 2 |  iter 6621 / 9295 | time 421[s] | loss 2.05
# | epoch 2 |  iter 6641 / 9295 | time 422[s] | loss 2.07
# | epoch 2 |  iter 6661 / 9295 | time 422[s] | loss 2.03
# | epoch 2 |  iter 6681 / 9295 | time 423[s] | loss 2.03
# | epoch 2 |  iter 6701 / 9295 | time 424[s] | loss 2.06
# | epoch 2 |  iter 6721 / 9295 | time 424[s] | loss 2.03
# | epoch 2 |  iter 6741 / 9295 | time 425[s] | loss 2.07
# | epoch 2 |  iter 6761 / 9295 | time 425[s] | loss 2.06
# | epoch 2 |  iter 6781 / 9295 | time 426[s] | loss 2.07
# | epoch 2 |  iter 6801 / 9295 | time 426[s] | loss 2.03
# | epoch 2 |  iter 6821 / 9295 | time 427[s] | loss 2.02
# | epoch 2 |  iter 6841 / 9295 | time 427[s] | loss 2.03
# | epoch 2 |  iter 6861 / 9295 | time 428[s] | loss 2.07
# | epoch 2 |  iter 6881 / 9295 | time 428[s] | loss 2.02
# | epoch 2 |  iter 6901 / 9295 | time 429[s] | loss 2.06
# | epoch 2 |  iter 6921 / 9295 | time 429[s] | loss 2.05
# | epoch 2 |  iter 6941 / 9295 | time 430[s] | loss 2.04
# | epoch 2 |  iter 6961 / 9295 | time 430[s] | loss 2.02
# | epoch 2 |  iter 6981 / 9295 | time 431[s] | loss 2.09
# | epoch 2 |  iter 7001 / 9295 | time 431[s] | loss 2.06
# | epoch 2 |  iter 7021 / 9295 | time 432[s] | loss 2.02
# | epoch 2 |  iter 7041 / 9295 | time 432[s] | loss 2.01
# | epoch 2 |  iter 7061 / 9295 | time 433[s] | loss 2.06
# | epoch 2 |  iter 7081 / 9295 | time 433[s] | loss 2.08
# | epoch 2 |  iter 7101 / 9295 | time 434[s] | loss 2.05
# | epoch 2 |  iter 7121 / 9295 | time 435[s] | loss 2.06
# | epoch 2 |  iter 7141 / 9295 | time 435[s] | loss 2.07
# | epoch 2 |  iter 7161 / 9295 | time 436[s] | loss 2.04
# | epoch 2 |  iter 7181 / 9295 | time 436[s] | loss 2.07
# | epoch 2 |  iter 7201 / 9295 | time 437[s] | loss 2.05
# | epoch 2 |  iter 7221 / 9295 | time 437[s] | loss 2.03
# | epoch 2 |  iter 7241 / 9295 | time 438[s] | loss 2.05
# | epoch 2 |  iter 7261 / 9295 | time 438[s] | loss 2.05
# | epoch 2 |  iter 7281 / 9295 | time 439[s] | loss 2.05
# | epoch 2 |  iter 7301 / 9295 | time 439[s] | loss 2.05
# | epoch 2 |  iter 7321 / 9295 | time 440[s] | loss 2.04
# | epoch 2 |  iter 7341 / 9295 | time 440[s] | loss 2.04
# | epoch 2 |  iter 7361 / 9295 | time 441[s] | loss 2.04
# | epoch 2 |  iter 7381 / 9295 | time 441[s] | loss 2.03
# | epoch 2 |  iter 7401 / 9295 | time 442[s] | loss 2.02
# | epoch 2 |  iter 7421 / 9295 | time 442[s] | loss 2.02
# | epoch 2 |  iter 7441 / 9295 | time 443[s] | loss 2.05
# | epoch 2 |  iter 7461 / 9295 | time 444[s] | loss 2.05
# | epoch 2 |  iter 7481 / 9295 | time 444[s] | loss 2.08
# | epoch 2 |  iter 7501 / 9295 | time 445[s] | loss 2.06
# | epoch 2 |  iter 7521 / 9295 | time 445[s] | loss 2.04
# | epoch 2 |  iter 7541 / 9295 | time 446[s] | loss 2.03
# | epoch 2 |  iter 7561 / 9295 | time 446[s] | loss 2.01
# | epoch 2 |  iter 7581 / 9295 | time 447[s] | loss 2.04
# | epoch 2 |  iter 7601 / 9295 | time 447[s] | loss 2.00
# | epoch 2 |  iter 7621 / 9295 | time 448[s] | loss 2.01
# | epoch 2 |  iter 7641 / 9295 | time 448[s] | loss 2.04
# | epoch 2 |  iter 7661 / 9295 | time 449[s] | loss 2.06
# | epoch 2 |  iter 7681 / 9295 | time 449[s] | loss 2.05
# | epoch 2 |  iter 7701 / 9295 | time 450[s] | loss 1.98
# | epoch 2 |  iter 7721 / 9295 | time 451[s] | loss 2.03
# | epoch 2 |  iter 7741 / 9295 | time 451[s] | loss 2.04
# | epoch 2 |  iter 7761 / 9295 | time 452[s] | loss 2.03
# | epoch 2 |  iter 7781 / 9295 | time 452[s] | loss 2.10
# | epoch 2 |  iter 7801 / 9295 | time 453[s] | loss 2.04
# | epoch 2 |  iter 7821 / 9295 | time 453[s] | loss 2.07
# | epoch 2 |  iter 7841 / 9295 | time 454[s] | loss 2.06
# | epoch 2 |  iter 7861 / 9295 | time 454[s] | loss 2.04
# | epoch 2 |  iter 7881 / 9295 | time 455[s] | loss 2.03
# | epoch 2 |  iter 7901 / 9295 | time 455[s] | loss 2.02
# | epoch 2 |  iter 7921 / 9295 | time 456[s] | loss 2.02
# ...
# | epoch 10 |  iter 3801 / 9295 | time 2365[s] | loss 1.47
# | epoch 10 |  iter 3821 / 9295 | time 2365[s] | loss 1.44
# | epoch 10 |  iter 3841 / 9295 | time 2366[s] | loss 1.45
# | epoch 10 |  iter 3861 / 9295 | time 2366[s] | loss 1.46
# | epoch 10 |  iter 3881 / 9295 | time 2367[s] | loss 1.42
# | epoch 10 |  iter 3901 / 9295 | time 2367[s] | loss 1.48
# | epoch 10 |  iter 3921 / 9295 | time 2368[s] | loss 1.45
# | epoch 10 |  iter 3941 / 9295 | time 2368[s] | loss 1.45
# | epoch 10 |  iter 3961 / 9295 | time 2369[s] | loss 1.41
# | epoch 10 |  iter 3981 / 9295 | time 2370[s] | loss 1.48
# | epoch 10 |  iter 4001 / 9295 | time 2370[s] | loss 1.41
# | epoch 10 |  iter 4021 / 9295 | time 2371[s] | loss 1.47
# | epoch 10 |  iter 4041 / 9295 | time 2371[s] | loss 1.45
# | epoch 10 |  iter 4061 / 9295 | time 2372[s] | loss 1.45
# | epoch 10 |  iter 4081 / 9295 | time 2372[s] | loss 1.45
# | epoch 10 |  iter 4101 / 9295 | time 2373[s] | loss 1.45
# | epoch 10 |  iter 4121 / 9295 | time 2373[s] | loss 1.45
# | epoch 10 |  iter 4141 / 9295 | time 2374[s] | loss 1.43
# | epoch 10 |  iter 4161 / 9295 | time 2375[s] | loss 1.44
# | epoch 10 |  iter 4181 / 9295 | time 2375[s] | loss 1.42
# | epoch 10 |  iter 4201 / 9295 | time 2376[s] | loss 1.43
# | epoch 10 |  iter 4221 / 9295 | time 2376[s] | loss 1.45
# | epoch 10 |  iter 4241 / 9295 | time 2377[s] | loss 1.45
# | epoch 10 |  iter 4261 / 9295 | time 2377[s] | loss 1.41
# | epoch 10 |  iter 4281 / 9295 | time 2378[s] | loss 1.46
# | epoch 10 |  iter 4301 / 9295 | time 2379[s] | loss 1.43
# | epoch 10 |  iter 4321 / 9295 | time 2379[s] | loss 1.44
# | epoch 10 |  iter 4341 / 9295 | time 2380[s] | loss 1.46
# | epoch 10 |  iter 4361 / 9295 | time 2380[s] | loss 1.46
# | epoch 10 |  iter 4381 / 9295 | time 2381[s] | loss 1.44
# | epoch 10 |  iter 4401 / 9295 | time 2381[s] | loss 1.44
# | epoch 10 |  iter 4421 / 9295 | time 2382[s] | loss 1.46
# | epoch 10 |  iter 4441 / 9295 | time 2382[s] | loss 1.43
# | epoch 10 |  iter 4461 / 9295 | time 2383[s] | loss 1.45
# | epoch 10 |  iter 4481 / 9295 | time 2383[s] | loss 1.41
# | epoch 10 |  iter 4501 / 9295 | time 2384[s] | loss 1.47
# | epoch 10 |  iter 4521 / 9295 | time 2385[s] | loss 1.45
# | epoch 10 |  iter 4541 / 9295 | time 2385[s] | loss 1.41
# | epoch 10 |  iter 4561 / 9295 | time 2386[s] | loss 1.49
# | epoch 10 |  iter 4581 / 9295 | time 2386[s] | loss 1.43
# | epoch 10 |  iter 4601 / 9295 | time 2387[s] | loss 1.41
# | epoch 10 |  iter 4621 / 9295 | time 2387[s] | loss 1.44
# | epoch 10 |  iter 4641 / 9295 | time 2388[s] | loss 1.43
# | epoch 10 |  iter 4661 / 9295 | time 2388[s] | loss 1.41
# | epoch 10 |  iter 4681 / 9295 | time 2389[s] | loss 1.43
# | epoch 10 |  iter 4701 / 9295 | time 2390[s] | loss 1.41
# | epoch 10 |  iter 4721 / 9295 | time 2390[s] | loss 1.43
# | epoch 10 |  iter 4741 / 9295 | time 2391[s] | loss 1.44
# | epoch 10 |  iter 4761 / 9295 | time 2391[s] | loss 1.47
# | epoch 10 |  iter 4781 / 9295 | time 2392[s] | loss 1.42
# | epoch 10 |  iter 4801 / 9295 | time 2393[s] | loss 1.45
# | epoch 10 |  iter 4821 / 9295 | time 2393[s] | loss 1.42
# | epoch 10 |  iter 4841 / 9295 | time 2394[s] | loss 1.42
# | epoch 10 |  iter 4861 / 9295 | time 2394[s] | loss 1.46
# | epoch 10 |  iter 4881 / 9295 | time 2395[s] | loss 1.43
# | epoch 10 |  iter 4901 / 9295 | time 2395[s] | loss 1.41
# | epoch 10 |  iter 4921 / 9295 | time 2396[s] | loss 1.46
# | epoch 10 |  iter 4941 / 9295 | time 2397[s] | loss 1.43
# | epoch 10 |  iter 4961 / 9295 | time 2397[s] | loss 1.46
# | epoch 10 |  iter 4981 / 9295 | time 2398[s] | loss 1.46
# | epoch 10 |  iter 5001 / 9295 | time 2398[s] | loss 1.44
# | epoch 10 |  iter 5021 / 9295 | time 2399[s] | loss 1.40
# | epoch 10 |  iter 5041 / 9295 | time 2399[s] | loss 1.47
# | epoch 10 |  iter 5061 / 9295 | time 2400[s] | loss 1.45
# | epoch 10 |  iter 5081 / 9295 | time 2401[s] | loss 1.45
# | epoch 10 |  iter 5101 / 9295 | time 2401[s] | loss 1.45
# | epoch 10 |  iter 5121 / 9295 | time 2402[s] | loss 1.42
# | epoch 10 |  iter 5141 / 9295 | time 2402[s] | loss 1.45
# | epoch 10 |  iter 5161 / 9295 | time 2403[s] | loss 1.44
# | epoch 10 |  iter 5181 / 9295 | time 2403[s] | loss 1.44
# | epoch 10 |  iter 5201 / 9295 | time 2404[s] | loss 1.47
# | epoch 10 |  iter 5221 / 9295 | time 2405[s] | loss 1.45
# | epoch 10 |  iter 5241 / 9295 | time 2405[s] | loss 1.44
# | epoch 10 |  iter 5261 / 9295 | time 2406[s] | loss 1.43
# | epoch 10 |  iter 5281 / 9295 | time 2406[s] | loss 1.44
# | epoch 10 |  iter 5301 / 9295 | time 2407[s] | loss 1.43
# | epoch 10 |  iter 5321 / 9295 | time 2407[s] | loss 1.46
# | epoch 10 |  iter 5341 / 9295 | time 2408[s] | loss 1.45
# | epoch 10 |  iter 5361 / 9295 | time 2409[s] | loss 1.48
# | epoch 10 |  iter 5381 / 9295 | time 2409[s] | loss 1.48
# | epoch 10 |  iter 5401 / 9295 | time 2410[s] | loss 1.43
# | epoch 10 |  iter 5421 / 9295 | time 2410[s] | loss 1.45
# | epoch 10 |  iter 5441 / 9295 | time 2411[s] | loss 1.44
# | epoch 10 |  iter 5461 / 9295 | time 2411[s] | loss 1.45
# | epoch 10 |  iter 5481 / 9295 | time 2412[s] | loss 1.44
# | epoch 10 |  iter 5501 / 9295 | time 2412[s] | loss 1.47
# | epoch 10 |  iter 5521 / 9295 | time 2413[s] | loss 1.40
# | epoch 10 |  iter 5541 / 9295 | time 2414[s] | loss 1.46
# | epoch 10 |  iter 5561 / 9295 | time 2414[s] | loss 1.42
# | epoch 10 |  iter 5581 / 9295 | time 2415[s] | loss 1.47
# | epoch 10 |  iter 5601 / 9295 | time 2415[s] | loss 1.42
# | epoch 10 |  iter 5621 / 9295 | time 2416[s] | loss 1.44
# | epoch 10 |  iter 5641 / 9295 | time 2416[s] | loss 1.44
# | epoch 10 |  iter 5661 / 9295 | time 2417[s] | loss 1.48
# | epoch 10 |  iter 5681 / 9295 | time 2417[s] | loss 1.42
# | epoch 10 |  iter 5701 / 9295 | time 2418[s] | loss 1.43
# | epoch 10 |  iter 5721 / 9295 | time 2419[s] | loss 1.45
# | epoch 10 |  iter 5741 / 9295 | time 2419[s] | loss 1.45
# | epoch 10 |  iter 5761 / 9295 | time 2420[s] | loss 1.44
# | epoch 10 |  iter 5781 / 9295 | time 2420[s] | loss 1.44
# | epoch 10 |  iter 5801 / 9295 | time 2421[s] | loss 1.43
# | epoch 10 |  iter 5821 / 9295 | time 2421[s] | loss 1.42
# | epoch 10 |  iter 5841 / 9295 | time 2422[s] | loss 1.43
# | epoch 10 |  iter 5861 / 9295 | time 2422[s] | loss 1.50
# | epoch 10 |  iter 5881 / 9295 | time 2423[s] | loss 1.47
# | epoch 10 |  iter 5901 / 9295 | time 2424[s] | loss 1.47
# | epoch 10 |  iter 5921 / 9295 | time 2424[s] | loss 1.50
# | epoch 10 |  iter 5941 / 9295 | time 2425[s] | loss 1.40
# | epoch 10 |  iter 5961 / 9295 | time 2425[s] | loss 1.44
# | epoch 10 |  iter 5981 / 9295 | time 2426[s] | loss 1.45
# | epoch 10 |  iter 6001 / 9295 | time 2426[s] | loss 1.45
# | epoch 10 |  iter 6021 / 9295 | time 2427[s] | loss 1.47
# | epoch 10 |  iter 6041 / 9295 | time 2427[s] | loss 1.46
# | epoch 10 |  iter 6061 / 9295 | time 2428[s] | loss 1.48
# | epoch 10 |  iter 6081 / 9295 | time 2429[s] | loss 1.41
# | epoch 10 |  iter 6101 / 9295 | time 2429[s] | loss 1.41
# | epoch 10 |  iter 6121 / 9295 | time 2430[s] | loss 1.49
# | epoch 10 |  iter 6141 / 9295 | time 2430[s] | loss 1.46
# | epoch 10 |  iter 6161 / 9295 | time 2431[s] | loss 1.46
# | epoch 10 |  iter 6181 / 9295 | time 2431[s] | loss 1.44
# | epoch 10 |  iter 6201 / 9295 | time 2432[s] | loss 1.41
# | epoch 10 |  iter 6221 / 9295 | time 2432[s] | loss 1.40
# | epoch 10 |  iter 6241 / 9295 | time 2433[s] | loss 1.46
# | epoch 10 |  iter 6261 / 9295 | time 2433[s] | loss 1.47
# | epoch 10 |  iter 6281 / 9295 | time 2434[s] | loss 1.46
# | epoch 10 |  iter 6301 / 9295 | time 2435[s] | loss 1.43
# | epoch 10 |  iter 6321 / 9295 | time 2435[s] | loss 1.38
# | epoch 10 |  iter 6341 / 9295 | time 2436[s] | loss 1.46
# | epoch 10 |  iter 6361 / 9295 | time 2436[s] | loss 1.45
# | epoch 10 |  iter 6381 / 9295 | time 2437[s] | loss 1.49
# | epoch 10 |  iter 6401 / 9295 | time 2437[s] | loss 1.45
# | epoch 10 |  iter 6421 / 9295 | time 2438[s] | loss 1.41
# | epoch 10 |  iter 6441 / 9295 | time 2438[s] | loss 1.43
# | epoch 10 |  iter 6461 / 9295 | time 2439[s] | loss 1.44
# | epoch 10 |  iter 6481 / 9295 | time 2440[s] | loss 1.45
# | epoch 10 |  iter 6501 / 9295 | time 2440[s] | loss 1.44
# | epoch 10 |  iter 6521 / 9295 | time 2441[s] | loss 1.42
# | epoch 10 |  iter 6541 / 9295 | time 2441[s] | loss 1.45
# | epoch 10 |  iter 6561 / 9295 | time 2442[s] | loss 1.40
# | epoch 10 |  iter 6581 / 9295 | time 2442[s] | loss 1.46
# | epoch 10 |  iter 6601 / 9295 | time 2443[s] | loss 1.48
# | epoch 10 |  iter 6621 / 9295 | time 2443[s] | loss 1.46
# | epoch 10 |  iter 6641 / 9295 | time 2444[s] | loss 1.42
# | epoch 10 |  iter 6661 / 9295 | time 2445[s] | loss 1.44
# | epoch 10 |  iter 6681 / 9295 | time 2445[s] | loss 1.50
# | epoch 10 |  iter 6701 / 9295 | time 2446[s] | loss 1.42
# | epoch 10 |  iter 6721 / 9295 | time 2446[s] | loss 1.46
# | epoch 10 |  iter 6741 / 9295 | time 2447[s] | loss 1.42
# | epoch 10 |  iter 6761 / 9295 | time 2447[s] | loss 1.46
# | epoch 10 |  iter 6781 / 9295 | time 2448[s] | loss 1.47
# | epoch 10 |  iter 6801 / 9295 | time 2448[s] | loss 1.44
# | epoch 10 |  iter 6821 / 9295 | time 2449[s] | loss 1.39
# | epoch 10 |  iter 6841 / 9295 | time 2449[s] | loss 1.44
# | epoch 10 |  iter 6861 / 9295 | time 2450[s] | loss 1.48
# | epoch 10 |  iter 6881 / 9295 | time 2451[s] | loss 1.44
# | epoch 10 |  iter 6901 / 9295 | time 2451[s] | loss 1.45
# | epoch 10 |  iter 6921 / 9295 | time 2452[s] | loss 1.44
# | epoch 10 |  iter 6941 / 9295 | time 2452[s] | loss 1.47
# | epoch 10 |  iter 6961 / 9295 | time 2453[s] | loss 1.51
# | epoch 10 |  iter 6981 / 9295 | time 2453[s] | loss 1.48
# | epoch 10 |  iter 7001 / 9295 | time 2454[s] | loss 1.46
# | epoch 10 |  iter 7021 / 9295 | time 2455[s] | loss 1.45
# | epoch 10 |  iter 7041 / 9295 | time 2455[s] | loss 1.44
# | epoch 10 |  iter 7061 / 9295 | time 2456[s] | loss 1.42
# | epoch 10 |  iter 7081 / 9295 | time 2456[s] | loss 1.44
# | epoch 10 |  iter 7101 / 9295 | time 2457[s] | loss 1.45
# | epoch 10 |  iter 7121 / 9295 | time 2457[s] | loss 1.44
# | epoch 10 |  iter 7141 / 9295 | time 2458[s] | loss 1.45
# | epoch 10 |  iter 7161 / 9295 | time 2458[s] | loss 1.44
# | epoch 10 |  iter 7181 / 9295 | time 2459[s] | loss 1.44
# | epoch 10 |  iter 7201 / 9295 | time 2459[s] | loss 1.44
# | epoch 10 |  iter 7221 / 9295 | time 2460[s] | loss 1.45
# | epoch 10 |  iter 7241 / 9295 | time 2461[s] | loss 1.41
# | epoch 10 |  iter 7261 / 9295 | time 2461[s] | loss 1.47
# | epoch 10 |  iter 7281 / 9295 | time 2462[s] | loss 1.45
# | epoch 10 |  iter 7301 / 9295 | time 2462[s] | loss 1.46
# | epoch 10 |  iter 7321 / 9295 | time 2463[s] | loss 1.44
# | epoch 10 |  iter 7341 / 9295 | time 2463[s] | loss 1.45
# | epoch 10 |  iter 7361 / 9295 | time 2464[s] | loss 1.42
# | epoch 10 |  iter 7381 / 9295 | time 2464[s] | loss 1.45
# | epoch 10 |  iter 7401 / 9295 | time 2465[s] | loss 1.45
# | epoch 10 |  iter 7421 / 9295 | time 2465[s] | loss 1.43
# | epoch 10 |  iter 7441 / 9295 | time 2466[s] | loss 1.48
# | epoch 10 |  iter 7461 / 9295 | time 2466[s] | loss 1.43
# | epoch 10 |  iter 7481 / 9295 | time 2467[s] | loss 1.45
# | epoch 10 |  iter 7501 / 9295 | time 2468[s] | loss 1.45
# | epoch 10 |  iter 7521 / 9295 | time 2468[s] | loss 1.44
# | epoch 10 |  iter 7541 / 9295 | time 2469[s] | loss 1.45
# | epoch 10 |  iter 7561 / 9295 | time 2469[s] | loss 1.46
# | epoch 10 |  iter 7581 / 9295 | time 2470[s] | loss 1.46
# | epoch 10 |  iter 7601 / 9295 | time 2470[s] | loss 1.46
# | epoch 10 |  iter 7621 / 9295 | time 2471[s] | loss 1.45
# | epoch 10 |  iter 7641 / 9295 | time 2471[s] | loss 1.46
# | epoch 10 |  iter 7661 / 9295 | time 2472[s] | loss 1.45
# | epoch 10 |  iter 7681 / 9295 | time 2472[s] | loss 1.45
# | epoch 10 |  iter 7701 / 9295 | time 2473[s] | loss 1.45
# | epoch 10 |  iter 7721 / 9295 | time 2473[s] | loss 1.48
# | epoch 10 |  iter 7741 / 9295 | time 2474[s] | loss 1.46
# | epoch 10 |  iter 7761 / 9295 | time 2475[s] | loss 1.46
# | epoch 10 |  iter 7781 / 9295 | time 2475[s] | loss 1.45
# | epoch 10 |  iter 7801 / 9295 | time 2476[s] | loss 1.44
# | epoch 10 |  iter 7821 / 9295 | time 2476[s] | loss 1.44
# | epoch 10 |  iter 7841 / 9295 | time 2477[s] | loss 1.46
# | epoch 10 |  iter 7861 / 9295 | time 2477[s] | loss 1.47
# | epoch 10 |  iter 7881 / 9295 | time 2478[s] | loss 1.48
# | epoch 10 |  iter 7901 / 9295 | time 2478[s] | loss 1.46
# | epoch 10 |  iter 7921 / 9295 | time 2479[s] | loss 1.46
# | epoch 10 |  iter 7941 / 9295 | time 2479[s] | loss 1.46
# | epoch 10 |  iter 7961 / 9295 | time 2480[s] | loss 1.44
# | epoch 10 |  iter 7981 / 9295 | time 2481[s] | loss 1.48
# | epoch 10 |  iter 8001 / 9295 | time 2481[s] | loss 1.43
# | epoch 10 |  iter 8021 / 9295 | time 2482[s] | loss 1.46
# | epoch 10 |  iter 8041 / 9295 | time 2482[s] | loss 1.45
# | epoch 10 |  iter 8061 / 9295 | time 2483[s] | loss 1.45
# | epoch 10 |  iter 8081 / 9295 | time 2483[s] | loss 1.46
# | epoch 10 |  iter 8101 / 9295 | time 2484[s] | loss 1.48
# | epoch 10 |  iter 8121 / 9295 | time 2484[s] | loss 1.41
# | epoch 10 |  iter 8141 / 9295 | time 2485[s] | loss 1.47
# | epoch 10 |  iter 8161 / 9295 | time 2486[s] | loss 1.47
# | epoch 10 |  iter 8181 / 9295 | time 2486[s] | loss 1.44
# | epoch 10 |  iter 8201 / 9295 | time 2487[s] | loss 1.48
# | epoch 10 |  iter 8221 / 9295 | time 2487[s] | loss 1.44
# | epoch 10 |  iter 8241 / 9295 | time 2488[s] | loss 1.45
# | epoch 10 |  iter 8261 / 9295 | time 2488[s] | loss 1.46
# | epoch 10 |  iter 8281 / 9295 | time 2489[s] | loss 1.44
# | epoch 10 |  iter 8301 / 9295 | time 2489[s] | loss 1.45
# | epoch 10 |  iter 8321 / 9295 | time 2490[s] | loss 1.41
# | epoch 10 |  iter 8341 / 9295 | time 2490[s] | loss 1.44
# | epoch 10 |  iter 8361 / 9295 | time 2491[s] | loss 1.44
# | epoch 10 |  iter 8381 / 9295 | time 2492[s] | loss 1.47
# | epoch 10 |  iter 8401 / 9295 | time 2492[s] | loss 1.42
# | epoch 10 |  iter 8421 / 9295 | time 2493[s] | loss 1.45
# | epoch 10 |  iter 8441 / 9295 | time 2493[s] | loss 1.42
# | epoch 10 |  iter 8461 / 9295 | time 2494[s] | loss 1.45
# | epoch 10 |  iter 8481 / 9295 | time 2494[s] | loss 1.47
# | epoch 10 |  iter 8501 / 9295 | time 2495[s] | loss 1.44
# | epoch 10 |  iter 8521 / 9295 | time 2495[s] | loss 1.44
# | epoch 10 |  iter 8541 / 9295 | time 2496[s] | loss 1.47
# | epoch 10 |  iter 8561 / 9295 | time 2496[s] | loss 1.45
# | epoch 10 |  iter 8581 / 9295 | time 2497[s] | loss 1.49
# | epoch 10 |  iter 8601 / 9295 | time 2498[s] | loss 1.47
# | epoch 10 |  iter 8621 / 9295 | time 2498[s] | loss 1.46
# | epoch 10 |  iter 8641 / 9295 | time 2499[s] | loss 1.49
# | epoch 10 |  iter 8661 / 9295 | time 2499[s] | loss 1.47
# | epoch 10 |  iter 8681 / 9295 | time 2500[s] | loss 1.45
# | epoch 10 |  iter 8701 / 9295 | time 2500[s] | loss 1.43
# | epoch 10 |  iter 8721 / 9295 | time 2501[s] | loss 1.41
# | epoch 10 |  iter 8741 / 9295 | time 2501[s] | loss 1.45
# | epoch 10 |  iter 8761 / 9295 | time 2502[s] | loss 1.48
# | epoch 10 |  iter 8781 / 9295 | time 2503[s] | loss 1.44
# | epoch 10 |  iter 8801 / 9295 | time 2503[s] | loss 1.43
# | epoch 10 |  iter 8821 / 9295 | time 2504[s] | loss 1.47
# | epoch 10 |  iter 8841 / 9295 | time 2504[s] | loss 1.47
# | epoch 10 |  iter 8861 / 9295 | time 2505[s] | loss 1.45
# | epoch 10 |  iter 8881 / 9295 | time 2505[s] | loss 1.45
# | epoch 10 |  iter 8901 / 9295 | time 2506[s] | loss 1.46
# | epoch 10 |  iter 8921 / 9295 | time 2506[s] | loss 1.47
# | epoch 10 |  iter 8941 / 9295 | time 2507[s] | loss 1.42
# | epoch 10 |  iter 8961 / 9295 | time 2507[s] | loss 1.45
# | epoch 10 |  iter 8981 / 9295 | time 2508[s] | loss 1.42
# | epoch 10 |  iter 9001 / 9295 | time 2508[s] | loss 1.48
# | epoch 10 |  iter 9021 / 9295 | time 2509[s] | loss 1.46
# | epoch 10 |  iter 9041 / 9295 | time 2510[s] | loss 1.43
# | epoch 10 |  iter 9061 / 9295 | time 2510[s] | loss 1.46
# | epoch 10 |  iter 9081 / 9295 | time 2511[s] | loss 1.49
# | epoch 10 |  iter 9101 / 9295 | time 2511[s] | loss 1.44
# | epoch 10 |  iter 9121 / 9295 | time 2512[s] | loss 1.44
# | epoch 10 |  iter 9141 / 9295 | time 2512[s] | loss 1.49
# | epoch 10 |  iter 9161 / 9295 | time 2513[s] | loss 1.46
# | epoch 10 |  iter 9181 / 9295 | time 2513[s] | loss 1.48
# | epoch 10 |  iter 9201 / 9295 | time 2514[s] | loss 1.48
# | epoch 10 |  iter 9221 / 9295 | time 2514[s] | loss 1.46
# | epoch 10 |  iter 9241 / 9295 | time 2515[s] | loss 1.43
# | epoch 10 |  iter 9261 / 9295 | time 2516[s] | loss 1.48
# | epoch 10 |  iter 9281 / 9295 | time 2516[s] | loss 1.46

# %% [markdown]
# ### 4.3.3 CBOW 모델 평가

# %%
from common.util import most_similar
import pickle

pkl_file = 'cbow_params.pkl'

with open(pkl_file, 'rb') as f:
  params = pickle.load(f)
  word_vecs = params['word_vecs']
  word_to_id = params['word_to_id']
  id_to_word = params['id_to_word']
  
querys = ['you', 'year', 'car', 'toyota']
for query in querys:
  most_similar(query, word_to_id, id_to_word, word_vecs, top=5)
# Out:
# [query] you
#  we: 0.6103515625
#  someone: 0.59130859375
#  i: 0.55419921875
#  something: 0.48974609375
#  anyone: 0.47314453125
#
# [query] year
#  month: 0.71875
#  week: 0.65234375
#  spring: 0.62744140625
#  summer: 0.6259765625
#  decade: 0.603515625
#
# [query] car
#  luxury: 0.497314453125
#  arabia: 0.47802734375
#  auto: 0.47119140625
#  disk-drive: 0.450927734375
#  travel: 0.4091796875
#
# [query] toyota
#  ford: 0.55078125
#  instrumentation: 0.509765625
#  mazda: 0.49365234375
#  bethlehem: 0.47509765625
#  nissan: 0.474853515625

# %% [markdown]
# **King - Man - Woman - Queen Test**
#
# word2vec의 단어의 분산 표현은 단어 사이의 관계를 잘 파악한다. 이를 확인하기 위해 'king - man - woman - queen' 테스트를 수행한다.

# %%
from common.util import analogy

analogy('king', 'man', 'woman', word_to_id, id_to_word, word_vecs)
analogy('france', 'paris', 'london', word_to_id, id_to_word, word_vecs)
analogy('france', 'paris', 'rome', word_to_id, id_to_word, word_vecs)
# Out:
# [analogy] king:man = woman:?
#  veto: 6.15234375
#  ms.: 5.5390625
#  successor: 5.39453125
#  wife: 5.30859375
#  husband: 5.2265625
#
# [analogy] france:paris = london:?
#  analyst: 5.8359375
#  interview: 5.73828125
#  zurich: 5.41796875
#  exchange: 5.04296875
#  over-the-counter: 4.8125
#
# [analogy] france:paris = rome:?
#  brothers: 4.3671875
#  street: 4.125
#  interview: 4.0
#  analyst: 3.98828125
#  san: 3.75390625
# 1 is not found
