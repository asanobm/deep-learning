# %%
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.datasets import mnist
import numpy as np

# all gpu should be used
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %%
# Check tensorflow device
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13380349820003918595
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 23365222400
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 6130650749948279520
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9"
# xla_global_id: 416903419
# , name: "/device:GPU:1"
# device_type: "GPU"
# memory_limit: 23365222400
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 16934262958898462278
# physical_device_desc: "device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:03:00.0, compute capability: 8.9"
# xla_global_id: 2144165316
# ]
# 2024-04-22 23:13:55.900397: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900543: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900629: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900698: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900765: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900833: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.900950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.901021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.901090: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.901148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:0 with 22282 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-04-22 23:13:55.901171: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-04-22 23:13:55.901225: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /device:GPU:1 with 22282 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:03:00.0, compute capability: 8.9

# %%
# hipermarametros

batch_size = 100
original_dim = 784
latent_dim = 2
intermediate_dim = 256
epochs = 100
epsilon_std = 0.7

# %%
# create incoder

x = Input(shape=(original_dim,))
h = Dense(intermediate_dim, activation="relu")(x)
z_mean = Dense(latent_dim)(h)
z_log_var = Dense(latent_dim)(h)
z = Lambda(
    lambda args: args[0]
    + K.random_normal(
        shape=(K.shape(args[0])[0], latent_dim), mean=0.0, stddev=epsilon_std
    )
    * K.exp(args[1] / 2),
    output_shape=(latent_dim,),
)([z_mean, z_log_var])

encoder = Model(x, [z_mean, z_log_var, z], name="encoder")

# %%
# create sampling function


def sampling(args: tuple):
    z_mean, z_log_var = args
    batch = K.shape(z_mean)[0]
    dim = K.int_shape(z_mean)[1]
    epsilon = K.random_normal(shape=(batch, dim), mean=0.0, stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# %%
# create decoder

input_decoder = Input(shape=(latent_dim,), name="decoder_input")

decoder_h = Dense(intermediate_dim, activation="relu", name="decoder_h")(input_decoder)

x_decoded = Dense(original_dim, activation="sigmoid", name="flat_decoded")(decoder_h)

decoder = Model(input_decoder, x_decoded, name="decoder")

# %%
# create vae
output_combined = decoder(encoder(x)[2])
vae = Model(x, output_combined)
vae.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  encoder (Functional)        [(None, 2),               201988
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 784)               202256
#
# =================================================================
# Total params: 404,244
# Trainable params: 404,244
# Non-trainable params: 0
# _________________________________________________________________

# %%
# loss function
kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)

vae.add_loss(K.mean(kl_loss) / original_dim)
vae.compile(optimizer="rmsprop", loss="binary_crossentropy")

# %%
# dataloads

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
# train
vae.fit(
    x_train,
    x_train,
    shuffle=True,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(x_test, x_test),
)
# Out:
# Epoch 1/100
# 2024-04-22 23:13:56.633711: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-04-22 23:13:56.646845: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fdd869a7b60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-22 23:13:56.646861: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-04-22 23:13:56.646864: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (1): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2024-04-22 23:13:56.649033: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-22 23:13:56.674685: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-04-22 23:13:56.674700: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:237] Used ptxas at ptxas
# 2024-04-22 23:13:56.675074: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2863 - val_loss: 0.2485
# Epoch 2/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2447 - val_loss: 0.2406
# Epoch 3/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2387 - val_loss: 0.2360
# Epoch 4/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2351 - val_loss: 0.2328
# Epoch 5/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2324 - val_loss: 0.2304
# Epoch 6/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2301 - val_loss: 0.2282
# Epoch 7/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2279 - val_loss: 0.2262
# Epoch 8/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2260 - val_loss: 0.2243
# Epoch 9/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2243 - val_loss: 0.2227
# Epoch 10/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2228 - val_loss: 0.2215
# Epoch 11/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2214 - val_loss: 0.2202
# Epoch 12/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2200 - val_loss: 0.2189
# Epoch 13/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2187 - val_loss: 0.2176
# Epoch 14/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2175 - val_loss: 0.2167
# Epoch 15/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2164 - val_loss: 0.2158
# Epoch 16/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2153 - val_loss: 0.2150
# Epoch 17/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2144 - val_loss: 0.2139
# Epoch 18/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2135 - val_loss: 0.2132
# Epoch 19/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2126 - val_loss: 0.2126
# Epoch 20/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2117 - val_loss: 0.2114
# Epoch 21/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2109 - val_loss: 0.2105
# Epoch 22/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2101 - val_loss: 0.2099
# Epoch 23/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2093 - val_loss: 0.2090
# Epoch 24/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2085 - val_loss: 0.2085
# Epoch 25/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2079 - val_loss: 0.2078
# Epoch 26/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2072 - val_loss: 0.2070
# Epoch 27/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2066 - val_loss: 0.2067
# Epoch 28/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2061 - val_loss: 0.2061
# Epoch 29/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.2055 - val_loss: 0.2056
# Epoch 30/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2050 - val_loss: 0.2051
# Epoch 31/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2046 - val_loss: 0.2047
# Epoch 32/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2040 - val_loss: 0.2044
# Epoch 33/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2036 - val_loss: 0.2043
# Epoch 34/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2031 - val_loss: 0.2033
# Epoch 35/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2027 - val_loss: 0.2029
# Epoch 36/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2023 - val_loss: 0.2034
# Epoch 37/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2018 - val_loss: 0.2026
# Epoch 38/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2014 - val_loss: 0.2018
# Epoch 39/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2010 - val_loss: 0.2023
# Epoch 40/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2006 - val_loss: 0.2012
# Epoch 41/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.2002 - val_loss: 0.2011
# Epoch 42/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1998 - val_loss: 0.2006
# Epoch 43/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1995 - val_loss: 0.2002
# Epoch 44/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1991 - val_loss: 0.1998
# Epoch 45/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1988 - val_loss: 0.1996
# Epoch 46/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1985 - val_loss: 0.1993
# Epoch 47/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1982 - val_loss: 0.1993
# Epoch 48/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1979 - val_loss: 0.1988
# Epoch 49/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1977 - val_loss: 0.1988
# Epoch 50/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1974 - val_loss: 0.1986
# Epoch 51/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1972 - val_loss: 0.1985
# Epoch 52/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1969 - val_loss: 0.1982
# Epoch 53/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1967 - val_loss: 0.1978
# Epoch 54/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1964 - val_loss: 0.1982
# Epoch 55/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1962 - val_loss: 0.1976
# Epoch 56/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1960 - val_loss: 0.1976
# Epoch 57/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1958 - val_loss: 0.1971
# Epoch 58/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1956 - val_loss: 0.1971
# Epoch 59/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1954 - val_loss: 0.1969
# Epoch 60/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1952 - val_loss: 0.1967
# Epoch 61/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1950 - val_loss: 0.1965
# Epoch 62/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1948 - val_loss: 0.1966
# Epoch 63/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1946 - val_loss: 0.1964
# Epoch 64/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1944 - val_loss: 0.1961
# Epoch 65/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1943 - val_loss: 0.1978
# Epoch 66/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1941 - val_loss: 0.1960
# Epoch 67/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1940 - val_loss: 0.1958
# Epoch 68/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1938 - val_loss: 0.1960
# Epoch 69/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1937 - val_loss: 0.1959
# Epoch 70/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1935 - val_loss: 0.1955
# Epoch 71/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1933 - val_loss: 0.1955
# Epoch 72/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1931 - val_loss: 0.1949
# Epoch 73/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1930 - val_loss: 0.1959
# Epoch 74/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1929 - val_loss: 0.1952
# Epoch 75/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1927 - val_loss: 0.1948
# Epoch 76/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1926 - val_loss: 0.1949
# Epoch 77/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1924 - val_loss: 0.1950
# Epoch 78/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1923 - val_loss: 0.1954
# Epoch 79/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1922 - val_loss: 0.1944
# Epoch 80/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1920 - val_loss: 0.1943
# Epoch 81/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1919 - val_loss: 0.1944
# Epoch 82/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1918 - val_loss: 0.1941
# Epoch 83/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1917 - val_loss: 0.1944
# Epoch 84/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1915 - val_loss: 0.1939
# Epoch 85/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1914 - val_loss: 0.1941
# Epoch 86/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1913 - val_loss: 0.1951
# Epoch 87/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1911 - val_loss: 0.1939
# Epoch 88/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1911 - val_loss: 0.1936
# Epoch 89/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1909 - val_loss: 0.1941
# Epoch 90/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1908 - val_loss: 0.1933
# Epoch 91/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1907 - val_loss: 0.1944
# Epoch 92/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1907 - val_loss: 0.1935
# Epoch 93/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1905 - val_loss: 0.1931
# Epoch 94/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1904 - val_loss: 0.1937
# Epoch 95/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1903 - val_loss: 0.1939
# Epoch 96/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1902 - val_loss: 0.1931
# Epoch 97/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1901 - val_loss: 0.1934
# Epoch 98/100
# 600/600 [==============================] - 1s 2ms/step - loss: 0.1900 - val_loss: 0.1934
# Epoch 99/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1899 - val_loss: 0.1930
# Epoch 100/100
# 600/600 [==============================] - 1s 1ms/step - loss: 0.1898 - val_loss: 0.1931

# %%
# show results
import matplotlib.pyplot as plt

n = 15
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = np.linspace(-15, 15, n)
grid_y = np.linspace(-15, 15, n)

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = decoder.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[
            i * digit_size : (i + 1) * digit_size, j * digit_size : (j + 1) * digit_size
        ] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure)
plt.show()
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
